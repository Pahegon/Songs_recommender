# %%
import spotipy
import pandas as pd
import config
import spotipy
import json
from spotipy.oauth2 import SpotifyClientCredentials
import pprint
from IPython.display import IFrame
import pprint
import random
from bs4 import BeautifulSoup
import requests

# %%
import pickle
import numpy as np
import pickle
from sklearn import datasets # sklearn comes with some toy datasets to practise
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from matplotlib import pyplot
from sklearn.metrics import silhouette_score

# %%
df_final = pd.read_csv('df_final_spotify.csv', index_col=0)
df_final
# Out:
#       danceability  energy  loudness  speechiness  acousticness  \
# 0            0.449   0.576   -10.640       0.0329       0.71200
# 1            0.404   0.902    -3.880       0.0665       0.57700
# 2            0.402   0.552   -10.158       0.0258       0.02800
# 3            0.338   0.340   -12.049       0.0339       0.58000
# 4            0.490   0.724    -9.581       0.0366       0.00976
# ...            ...     ...       ...          ...           ...
# 6128         0.868   0.550    -6.417       0.2260       0.18300
# 6129         0.701   0.650    -6.313       0.1040       0.29100
# 6130         0.630   0.446    -8.900       0.0351       0.33700
# 6131         0.625   0.814    -5.181       0.0657       0.01720
# 6132         0.288   0.638    -6.935       0.0779       0.13300
#
#       instrumentalness  liveness  valence    tempo                      id  \
# 0             0.000000    0.1650    0.599   95.653  0Muez8ucUqZMXIaYONOgF2
# 1             0.297000    0.2870    0.497  115.669  2kkvB3RNRzwjFdGhaUA0tz
# 2             0.000014    0.0929    0.668  145.164  3m7V717IKZqZLW5qUIOxdD
# 3             0.003200    0.1160    0.197   82.433  5CQ30WqJwcep0pYcV4AMNc
# 4             0.004600    0.1590    0.292  125.812  4qgZs0RNjdzKAS22lP0QjY
# ...                ...       ...      ...      ...                     ...
# 6128          0.000000    0.1090    0.464  117.943  0fCwrjKfWxF3xQhZrYUw4T
# 6129          0.000000    0.1120    0.647   90.003  0ada5XsQGLPUVbmTCkAP49
# 6130          0.000000    0.1660    0.177  143.078  5wWAwzGp2OaaoIkwcz6wZs
# 6131          0.000000    0.1580    0.535  144.991  2Y0wPrPQBrGhoLn14xRYCG
# 6132          0.000082    0.1400    0.147   66.424  2SVx3uds6jTWALFxevIWMA
#
#       duration_ms  cluster
# 0          367507        4
# 1          423840        2
# 2          431333        2
# 3          482830        2
# 4          337506        2
# ...           ...      ...
# 6128       154767        7
# 6129       160212        5
# 6130       202193        4
# 6131       205485        6
# 6132       173114        1
#
# [6133 rows x 12 columns]

# %%
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id= config.client_id,
                                                           client_secret= config.client_secret))

# %%
df= pd.read_csv('billboard hot 100')
df
# Out:
#     Unnamed: 0                                    song  \
# 0            0                               as it was
# 1            1                               bad habit
# 2            2                         about damn time
# 3            3  running up that hill (a deal with god)
# 4            4                                 sunroof
# ..         ...                                     ...
# 95          95                 thought you should know
# 96          96                 2 be loved (am i ready)
# 97          97                       wait in the truck
# 98          98                            la corriente
# 99          99            bzrp music sessions, vol. 52
#
#                            artist
# 0                    harry styles
# 1                      steve lacy
# 2                           lizzo
# 3                       kate bush
# 4              nicky youre & dazy
# ..                            ...
# 95                  morgan wallen
# 96                          lizzo
# 97  hardy featuring lainey wilson
# 98          bad bunny & tony dize
# 99             bizarrap & quevedo
#
# [100 rows x 3 columns]

# %%
import difflib

# %%
df
# Out:
#     Unnamed: 0                                    song  \
# 0            0                               as it was
# 1            1                               bad habit
# 2            2                         about damn time
# 3            3  running up that hill (a deal with god)
# 4            4                                 sunroof
# ..         ...                                     ...
# 95          95                 thought you should know
# 96          96                 2 be loved (am i ready)
# 97          97                       wait in the truck
# 98          98                            la corriente
# 99          99            bzrp music sessions, vol. 52
#
#                            artist
# 0                    harry styles
# 1                      steve lacy
# 2                           lizzo
# 3                       kate bush
# 4              nicky youre & dazy
# ..                            ...
# 95                  morgan wallen
# 96                          lizzo
# 97  hardy featuring lainey wilson
# 98          bad bunny & tony dize
# 99             bizarrap & quevedo
#
# [100 rows x 3 columns]

# %% [markdown]
# # Receive an input song from a user. let’s imagine it’s Bohemian Rhapsody

# %%
user = input("select your song : ")

difflib.get_close_matches(user, df['song'])

if user in list(df['song']):
    computer = random.choice(df['song'])
    print('Recommendation:',computer)
elif difflib.get_close_matches(user, df['song']):
    computer = random.choice(df['song'])
    print('do you mean:',difflib.get_close_matches(user, df['song'])[0],'?')
    user2=input()
    
    if user2 == 'yes':
        print('Recommendation:',computer)
    elif user2 == 'no':
        print('Unfortunately, the song is not in the hot list!')
    else:
        print('please select yes or no:')
        user2=input()        
else: 
    print('Unfortunately, the song is not in the hot list!')
# Out:
# select your song : la cosa
# Unfortunately, the song is not in the hot list!

# %% [markdown]
# # Get “Bohemian Rhapsody” features

# %%
#send “Bohemian Rhapsody” to the Spotify API and get its audio features. store them in a variable in this case: users_track
results = sp.search(q=user,limit=3,market="GB")
results
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=la+cosa&type=track&market=GB&offset=0&limit=3',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4E0mDf341TLViBbNefSrsK'},
#        'href': 'https://api.spotify.com/v1/artists/4E0mDf341TLViBbNefSrsK',
#        'id': '4E0mDf341TLViBbNefSrsK',
#        'name': 'Blade Brown',
#        'type': 'artist',
#        'uri': 'spotify:artist:4E0mDf341TLViBbNefSrsK'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/39XT9gMoNmMCOlvTTR273m'},
#        'href': 'https://api.spotify.com/v1/artists/39XT9gMoNmMCOlvTTR273m',
#        'id': '39XT9gMoNmMCOlvTTR273m',
#        'name': 'K-Trap',
#        'type': 'artist',
#        'uri': 'spotify:artist:39XT9gMoNmMCOlvTTR273m'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4KjjsmwK9VsIiOxydoFRU0'},
#      'href': 'https://api.spotify.com/v1/albums/4KjjsmwK9VsIiOxydoFRU0',
#      'id': '4KjjsmwK9VsIiOxydoFRU0',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2731d2d1a729e145ba0295e4e9e',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e021d2d1a729e145ba0295e4e9e',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048511d2d1a729e145ba0295e4e9e',
#        'width': 64}],
#      'name': 'Joints',
#      'release_date': '2022-03-25',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:4KjjsmwK9VsIiOxydoFRU0'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4E0mDf341TLViBbNefSrsK'},
#       'href': 'https://api.spotify.com/v1/artists/4E0mDf341TLViBbNefSrsK',
#       'id': '4E0mDf341TLViBbNefSrsK',
#       'name': 'Blade Brown',
#       'type': 'artist',
#       'uri': 'spotify:artist:4E0mDf341TLViBbNefSrsK'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/39XT9gMoNmMCOlvTTR273m'},
#       'href': 'https://api.spotify.com/v1/artists/39XT9gMoNmMCOlvTTR273m',
#       'id': '39XT9gMoNmMCOlvTTR273m',
#       'name': 'K-Trap',
#       'type': 'artist',
#       'uri': 'spotify:artist:39XT9gMoNmMCOlvTTR273m'}],
#     'disc_number': 1,
#     'duration_ms': 124969,
#     'explicit': True,
#     'external_ids': {'isrc': 'TCAGB2280440'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6cKY3r8eod22IjDLcDjoaj'},
#     'href': 'https://api.spotify.com/v1/tracks/6cKY3r8eod22IjDLcDjoaj',
#     'id': '6cKY3r8eod22IjDLcDjoaj',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'La Cosa Nostra',
#     'popularity': 48,
#     'preview_url': 'https://p.scdn.co/mp3-preview/06fd8b7b10036cddbe69e11f6319f89b9b1d0ca0?cid=98dc7c7d465a4e7fbe9af18fca43455a',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:6cKY3r8eod22IjDLcDjoaj'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/61J0BktHv7PuP3tjTPYXSX'},
#        'href': 'https://api.spotify.com/v1/artists/61J0BktHv7PuP3tjTPYXSX',
#        'id': '61J0BktHv7PuP3tjTPYXSX',
#        'name': 'Eros Ramazzotti',
#        'type': 'artist',
#        'uri': 'spotify:artist:61J0BktHv7PuP3tjTPYXSX'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/49oNMRzQcMBCqiz03JOQqq'},
#      'href': 'https://api.spotify.com/v1/albums/49oNMRzQcMBCqiz03JOQqq',
#      'id': '49oNMRzQcMBCqiz03JOQqq',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27382275cd567e80f83c921fccd',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0282275cd567e80f83c921fccd',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485182275cd567e80f83c921fccd',
#        'width': 64}],
#      'name': 'Donde Hay Música (Spanish Version)',
#      'release_date': '1996-05-01',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:49oNMRzQcMBCqiz03JOQqq'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/61J0BktHv7PuP3tjTPYXSX'},
#       'href': 'https://api.spotify.com/v1/artists/61J0BktHv7PuP3tjTPYXSX',
#       'id': '61J0BktHv7PuP3tjTPYXSX',
#       'name': 'Eros Ramazzotti',
#       'type': 'artist',
#       'uri': 'spotify:artist:61J0BktHv7PuP3tjTPYXSX'}],
#     'disc_number': 1,
#     'duration_ms': 265626,
#     'explicit': False,
#     'external_ids': {'isrc': 'ITB009600578'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1EZypwk0xcj64ZLAglhLs2'},
#     'href': 'https://api.spotify.com/v1/tracks/1EZypwk0xcj64ZLAglhLs2',
#     'id': '1EZypwk0xcj64ZLAglhLs2',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'La Cosa Mas Bella',
#     'popularity': 71,
#     'preview_url': 'https://p.scdn.co/mp3-preview/5865822668a2f4f0a79cde8b52d1a8b15aaa83a2?cid=98dc7c7d465a4e7fbe9af18fca43455a',
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:1EZypwk0xcj64ZLAglhLs2'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4BldMaV12hGrR7KhZK6CYo'},
#      'href': 'https://api.spotify.com/v1/albums/4BldMaV12hGrR7KhZK6CYo',
#      'id': '4BldMaV12hGrR7KhZK6CYo',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273ef7373db37945a8052e0d456',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02ef7373db37945a8052e0d456',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851ef7373db37945a8052e0d456',
#        'width': 64}],
#      'name': 'Latin Rock Classics',
#      'release_date': '2022-09-15',
#      'release_date_precision': 'day',
#      'total_tracks': 22,
#      'type': 'album',
#      'uri': 'spotify:album:4BldMaV12hGrR7KhZK6CYo'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2F9pvj94b52wGKs0OqiNi2'},
#       'href': 'https://api.spotify.com/v1/artists/2F9pvj94b52wGKs0OqiNi2',
#       'id': '2F9pvj94b52wGKs0OqiNi2',
#       'name': 'Babasónicos',
#       'type': 'artist',
#       'uri': 'spotify:artist:2F9pvj94b52wGKs0OqiNi2'}],
#     'disc_number': 1,
#     'duration_ms': 242520,
#     'explicit': False,
#     'external_ids': {'isrc': 'ARUM70800269'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1MtyUDvTAOz2ewRPlEAiLj'},
#     'href': 'https://api.spotify.com/v1/tracks/1MtyUDvTAOz2ewRPlEAiLj',
#     'id': '1MtyUDvTAOz2ewRPlEAiLj',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Como Eran Las Cosas',
#     'popularity': 0,
#     'preview_url': None,
#     'track_number': 10,
#     'type': 'track',
#     'uri': 'spotify:track:1MtyUDvTAOz2ewRPlEAiLj'}],
#   'limit': 3,
#   'next': 'https://api.spotify.com/v1/search?query=la+cosa&type=track&market=GB&offset=3&limit=3',
#   'offset': 0,
#   'previous': None,
#   'total': 10436}}

# %%
track_id=track_id=results["tracks"]["items"][0]["id"]
track_id
# Out:
# '6cKY3r8eod22IjDLcDjoaj'

# %%
from IPython.display import IFrame

# %%
def play_song(track_id):
    return IFrame(src="https://open.spotify.com/embed/track/"+track_id,
       width="320",
       height="80",
       frameborder="0",
       allowtransparency="true",
       allow="encrypted-media",
      )

# %%
play_song(track_id)
# Out:
#         <iframe
#             width="320"
#             height="80"
#             src="https://open.spotify.com/embed/track/6cKY3r8eod22IjDLcDjoaj?frameborder=0&allowtransparency=true&allow=encrypted-media"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
users_track=sp.audio_features(results["tracks"]["items"][0]["id"] )

# %%
users_track
# Out:
# [{'danceability': 0.87,
#   'energy': 0.617,
#   'key': 1,
#   'loudness': -8.165,
#   'mode': 1,
#   'speechiness': 0.375,
#   'acousticness': 0.121,
#   'instrumentalness': 0,
#   'liveness': 0.153,
#   'valence': 0.63,
#   'tempo': 77.021,
#   'type': 'audio_features',
#   'id': '6cKY3r8eod22IjDLcDjoaj',
#   'uri': 'spotify:track:6cKY3r8eod22IjDLcDjoaj',
#   'track_href': 'https://api.spotify.com/v1/tracks/6cKY3r8eod22IjDLcDjoaj',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6cKY3r8eod22IjDLcDjoaj',
#   'duration_ms': 124970,
#   'time_signature': 4}]

# %% [markdown]
# # Scale the features

# %%
#Let's create a df with the features of the user's track
df_user=pd.DataFrame(users_track) 
df_user
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.87   0.617    1    -8.165     1        0.375         0.121
#
#    instrumentalness  liveness  valence   tempo            type  \
# 0                 0     0.153     0.63  77.021  audio_features
#
#                        id                                   uri  \
# 0  6cKY3r8eod22IjDLcDjoaj  spotify:track:6cKY3r8eod22IjDLcDjoaj
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/6cKY3r8eod22...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/6cKY...       124970
#
#    time_signature
# 0               4

# %%
#We create a new df with the same columns the songs of my song's collection
X = df_user[['danceability', 'energy', 'loudness', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo','duration_ms']].copy()

X
# Out:
#    danceability  energy  loudness  speechiness  acousticness  \
# 0          0.87   0.617    -8.165        0.375         0.121
#
#    instrumentalness  liveness  valence   tempo  duration_ms
# 0                 0     0.153     0.63  77.021       124970

# %%
#Scale the audio features using song_scaled = scaler.transform(song_audio_features) (this is the scaler we created above!)

# %%
def load(filename = "scaler.pkl"): 
    try: 
        with open(filename, "rb") as f: 
            return pickle.load(f) 
        
    except FileNotFoundError: 
        print("File not found!")

# %%
my_scaler = load("scaler.pkl")

# %%
X_scaled=my_scaler.transform(X)

# %%
X_scaled
# Out:
# array([[ 1.49076884, -0.31037952, -0.37075067,  2.2156973 , -0.35573858,
#         -0.23981538, -0.24030471,  0.48958123, -1.47826908, -1.42880823]])

# %% [markdown]
# # Get the cluster (from my model) of the user's song

# %%
#get the cluster of the song. 
#First we need to call the modell with 8 clusters I already created
def load(filename = "filename.pickle"): 
    try: 
        with open(filename, "rb") as f: 
            return pickle.load(f) 
        
    except FileNotFoundError: 
        print("File not found!")

# %%
my_model = pickle.load(open('kmeans8.pkl', 'rb'))
my_model_final=my_model.predict(X_scaled)
my_model_final
# Out:
# /Users/pabloherranzgonzalez/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but KMeans was fitted with feature names
#   warnings.warn(
# array([7], dtype=int32)

# %%
#It's in cluster 2. get a song randomly that belongs to cluster 2 and recomende it

# %%
#let's create a cluster column in the original df (df_final)

# %%
my_classification = df_final.loc[df_final['cluster']==my_model_final[0]]
my_classification
# Out:
#       danceability  energy  loudness  speechiness  acousticness  \
# 14           0.636   0.670   -10.958        0.257        0.5820
# 62           0.401   0.893   -11.171        0.437        0.0617
# 120          0.612   0.665    -9.830        0.390        0.0482
# 521          0.610   0.676    -8.212        0.256        0.6400
# 551          0.539   0.808    -4.160        0.198        0.3210
# ...            ...     ...       ...          ...           ...
# 6114         0.718   0.660    -7.390        0.325        0.3630
# 6115         0.908   0.648    -5.218        0.343        0.2310
# 6118         0.561   0.785    -5.376        0.452        0.1110
# 6121         0.926   0.542    -5.064        0.293        0.1350
# 6128         0.868   0.550    -6.417        0.226        0.1830
#
#       instrumentalness  liveness  valence    tempo                      id  \
# 14            0.000000    0.0453    0.572  115.577  0vVbjqqiJM19pKJLNUN6n0
# 62            0.039100    0.1640    0.406   87.979  3OuMIIFP5TxM8tLXMWYPGV
# 120           0.000001    0.0425    0.690  133.021  530Nh8H6UdeIZmxf9y7NXl
# 521           0.000060    0.3370    0.817  129.684  7nbzvThgq44C1X56D4RZuL
# 551           0.000000    0.2950    0.605   86.204  0YMBSfBIH4uhtorLtUdKeP
# ...                ...       ...      ...      ...                     ...
# 6114          0.000000    0.1590    0.659  142.879  2SxR5RitJdsG6wINvJLBSD
# 6115          0.000000    0.1040    0.374  138.992  0H2s2OnUAcK3oHi1EbrXaw
# 6118          0.000000    0.1210    0.458  150.159  2ppse4DOEFlzaW7Xu3U76r
# 6121          0.000000    0.0877    0.564  135.140  6gxKUmycQX7uyMwJcweFjp
# 6128          0.000000    0.1090    0.464  117.943  0fCwrjKfWxF3xQhZrYUw4T
#
#       duration_ms  cluster
# 14         377747        7
# 62         334555        7
# 120        188840        7
# 521        420667        7
# 551        211952        7
# ...           ...      ...
# 6114       132587        7
# 6115       170935        7
# 6118       180800        7
# 6121       181929        7
# 6128       154767        7
#
# [967 rows x 12 columns]

# %%
my_classification_id = list(my_classification['id'])
my_classification_id
# Out:
# ['0vVbjqqiJM19pKJLNUN6n0',
#  '3OuMIIFP5TxM8tLXMWYPGV',
#  '530Nh8H6UdeIZmxf9y7NXl',
#  '7nbzvThgq44C1X56D4RZuL',
#  '0YMBSfBIH4uhtorLtUdKeP',
#  '7LRMbd3LEoV5wZJvXT1Lwb',
#  '3FUS56gKr9mVBmzvlnodlh',
#  '0hCB0YR03f6AmQaHbwWDe8',
#  '3UP7dzy4ISy8S3HOReCd1q',
#  '702JBOmVd5CHvo6DExxWXU',
#  '2uyfLA0lkVWWljrkDkUT0q',
#  '1FGKQioiWwo0m38jnpbRPl',
#  '6WkFMoy0D6WV29Yi7vOznS',
#  '785t3poQsvdkSeH5xGA9R4',
#  '4HFUWx6MDdU8u2j3FOQ48V',
#  '6nwAubYnLGl7F7cDuOoVLp',
#  '1Q7wW9kZTBqM0YNq4dhatb',
#  '5MfzdAlm5SWSnU8WVCCznW',
#  '7i1nzuzVU0y6XzGdVMJDoI',
#  '54cOByTOIGV1XhhNm5e52z',
#  '1f6CFsufAwVPHrcNdlACRQ',
#  '3hQCHzkE5oSA3F1xM8bpcM',
#  '06KuuHD7I5esMuevpFqfxW',
#  '4xOTVtbCPcfxMs2hSt9D6i',
#  '3xv229qX6gFRYgplFCTKBl',
#  '0B8drtTSp68pZdkmVrG9ZA',
#  '3uqinR4FCjLv28bkrTdNX5',
#  '2UiAq5nThvcGnfEywIZth1',
#  '0lOe1dR2TNkJMCjIcRuw6T',
#  '1rJrDaAVtS9g5ij4T88Rj5',
#  '2RsXDjlhJd8sylorcY4r0o',
#  '7kgsCXovBYFMmb9eBMbWvn',
#  '1rCugBa2t3ycgyR4xHSvvA',
#  '2uhnzF1F605tp9QS6rH2VW',
#  '4QNJd8ma02Oy9PBenHErs1',
#  '7eRQVK7VtetceBAaBMWXXr',
#  '2L61rcZV7lAZCFyyFmehpy',
#  '1JPea9jubEk7rfIzJBaRDB',
#  '2FbJ1xr7Cn5bGKcF17Oj0U',
#  '5880eYQmXx3c3oD22IljIt',
#  '23qpfRkkOK4IrbVxIHQQIC',
#  '4jtyUzZm9WLc2AdaJ1dso7',
#  '57ABXArOh6Iit9v9uzj7gl',
#  '308T3ASJI1HJYLzR1WkWAx',
#  '1FKLwRWchfEQIDdTaw4pj5',
#  '30KKYkJ0lonfKI2eaLACnZ',
#  '5YmEfeehpYH0NaWG30yh9P',
#  '30kY0saQlvZ6tAJWhlDf6h',
#  '4R2ibsoF3A9Tv64DjEfyj9',
#  '4jxKAwocvyn4nKUbA7rBU8',
#  '4TGHOWSNAwUXn5onDQr0P1',
#  '5C2s6xPJL8klsKhm0GMLYx',
#  '2n7h09QrGitVul66b2D8Re',
#  '7gkYQOsR1xsFOqXeys4sYA',
#  '5byHoShbSK7mxLGDQZli9J',
#  '3cruThftOq6AYda82nQz3C',
#  '3PA9dH8cT0wR5UW4XkC44Y',
#  '3tC8SJpOwJhDg8WGG1NKGR',
#  '5byUj7I3UEZFyZcEQY9osu',
#  '52A8OAP8lTQKZCj4Rce92B',
#  '7vJJvoWJQceVrjj4zaFUch',
#  '70fwL8BxBBR3YcOPo9iS2h',
#  '1l0zeniK8MayaQedrPUK9n',
#  '4xa4rQgw5HPOGHEFwbRZCP',
#  '0sIt2GqJQ8s2CF27INgktz',
#  '0kPqzhHvq2SAiNkfDZ1PA8',
#  '3vQir0wkIdLGq3Lc4V6J2y',
#  '4hNslCMuTS83UAmRQr5DFA',
#  '5lFDtgWsjRJu8fPOAyJIAK',
#  '4Cw6NodTuyXSBJmz6nZzrL',
#  '73TsWp9NIkevkBxQY4plAK',
#  '4RRvVSpreSh8psHZodRUU7',
#  '23RJg00mFONjIqYML6mtsE',
#  '4KxIW9rRwmQYb27ya4HGiI',
#  '2zJ4fZY3Mevo75wJtmG9Ud',
#  '27u3Rh4IWYPdwVST20ALrt',
#  '3iyZRwIGmyXvdZMoxOlur7',
#  '7xXvPyOiFCsB5SSpio5g38',
#  '1EyH7MYN5CvdpFWqhDeT9K',
#  '6MzeC1EEq9TVkKgTCKtZ4V',
#  '2p9sprAX27D6U5cuSE9NsM',
#  '0KbIwqCAHmXWu7hrszXY6j',
#  '7iL6o9tox1zgHpKUfh9vuC',
#  '6js4GbrJjNU0Kp5ipDQ9vc',
#  '3iQHtjDo1jgcbjUPsh3Dkb',
#  '4WEuEfFiczWxblHyuucSBL',
#  '7dDLHlyZJBqEWSndlPWyCT',
#  '2KrkWcSP0oFWBUZzvj9KjS',
#  '58YBY8OiX56vQhcHUgul9m',
#  '3rhpXH6C6szCFlXyUwnWPG',
#  '7C51GjZkKPzBa6LKrNgYBv',
#  '7E6cKQcGpPqsr3eqnpnw0C',
#  '5Tl0HJvynZtKdSUMKbFVVX',
#  '63BokRfXSQhEU6Qi2dSJpZ',
#  '3LRKsq5TZsjOfbylaY7Izf',
#  '2kM3gIkHRiikiaIUFk3Fje',
#  '4JGBFzdgko5YaoaY9kN6cS',
#  '5XkeTGKcCkGF8l6fA9YpsS',
#  '60tnkjYNeiG5pvv4WdTv6w',
#  '0tVOnwMMukVoXOkNeTUcXc',
#  '5n86k4ft5H7OK4qdSUfYoz',
#  '0hvxqftYCZT406ElE03giM',
#  '3glqlA5qY3bbo8UaUDGPnw',
#  '4XifYC1TlOvfjzEZBTnBG1',
#  '4IYKjN1DrYzxKXt0umJqsG',
#  '5VOss7ATiPrSUzMkWZ3cTu',
#  '5pzw2ynaNVtsUktQBHqUe8',
#  '6bO0RKtbyVtaKcNwvX8VUt',
#  '09cgBMBJG5cffRUUyyC5ix',
#  '4EQ0dK6Sg7v685NGrQvuki',
#  '0GaNkRAiVdHDI7XzMZkL4g',
#  '6y6N5Yq1xCZjIfI6mC4BmE',
#  '6EwoActKsMjLj0C48E62Z2',
#  '6MJKEl0VVhW37OZMtt1RCo',
#  '2El2AmJcz6trXPVeXamGYC',
#  '3nsxMrnYlfBNotHRevTRgM',
#  '4Ix8BBZ5b2V61R2kABW4Hy',
#  '6bM9kqHeue1ryEKmZdM5Mv',
#  '5GgeOAiiaPPXTTKrLIOolH',
#  '5TeGunIS6RrgmLs8ZIkYBI',
#  '1wKXq2v6jbWPM2hH2uj0bx',
#  '2YlvHjDb4Tyxl4A1IcDhAe',
#  '0DdShCGVMmKJjRM078WtLm',
#  '7N1Vjtzr1lmmCW9iasQ8YO',
#  '1RjU7UhRICmdFPKxCucLgq',
#  '6QdVBqkKNUqCqercvUHMkP',
#  '6m49tZii9UUttOgDozxjI1',
#  '4AE7Lj39VnSZNOmGH2iZaq',
#  '24S7rWWB6ohk2j5ABrm5DJ',
#  '1z2wDNApaSPjp2IHPbvJ7D',
#  '2c5Isyd07hWsl7AQia2Dig',
#  '2yWjRvQGfBwcoOVWhdOMyX',
#  '5STdMlrBf6pqWiNE7WqxSi',
#  '0OW1giby0jqdaXrLPz6IUk',
#  '6iptJG5VQS440ZIiStMF0k',
#  '44WG43lprS0ZO3zQEBBOEc',
#  '18lRXAROle06PhNpCqRoSV',
#  '4ruvVeQQ97PZW7ucSkjfx7',
#  '19OHDib8Jrqi3o2nm5lzdA',
#  '4ZLNj4Zlp6XZ3WAVpPQEnq',
#  '5NRTJg50waeEr4M603gIqq',
#  '4CgVADr5mX2tATGxVemeRm',
#  '5z37OkOEzss0a6F5bxjlkS',
#  '5czjjnbTatyFal33a9h1aN',
#  '3bVRaCHhYFkm606nFNP5ce',
#  '0UfMTXvLlFMsMz99qsA6RE',
#  '7nfy1l7LJ8dMKwKpupSvrG',
#  '2kOCrXu50fbNCs9xvdtjuQ',
#  '39K1WK0C9HINrG52PH9qoZ',
#  '4B5m8hNujbPhE21bc0NzRA',
#  '4bHrZLxaOU1gfAz0rZAnCx',
#  '0Ry7r99zkyV0OAcPQytzDe',
#  '02rlDATSROFtjqmvs1dBKr',
#  '4anqYZt4APNlFwQixpbdZR',
#  '1g4JhDdefwqIOgXM2XJZlC',
#  '4m3cBz9bSuRiStMJ6KgHMG',
#  '6KDBhwxlHJayUAKwPCmh3F',
#  '0t4hFog8Bsj3yIKUEc2Fh8',
#  '48tybOd2kxWaMjnYrEWTvY',
#  '3tj3XocQFj5rfJaSgXWWV2',
#  '6C4eykRsTZQPXaTmig5N40',
#  '2CxOJwC4jqWfPQdahEX9oH',
#  '3Y6XWs8xMlCngyIxNOFnsp',
#  '2L37qQvSqW1go6Sq0HPTxW',
#  '62l1ZGNoUlJlVwhwMKu2T6',
#  '1LDrfhiRTyIMpigi5G1YyA',
#  '3vZO25GdYuqFrR1kzZADnp',
#  '1Ov4E4nE7E0yzeqpbhEE5g',
#  '3kJrESsM3ISObFTfBQfJ8H',
#  '2hSHuzSSGQLQor4iIiYw4Z',
#  '10HKFfz0P26COpxc6xYJyU',
#  '2MNQMtZbOb7rBWli3TSok0',
#  '47im4z15sXA8sQxD16E0dY',
#  '47WdJSuQsaWVv5pUjiOASL',
#  '60uesDF4UyLUs61FgiDkdp',
#  '5dPX5OzasrD7uCe1Nr66qP',
#  '7ivM5ILtz3k5Z6sRjXu0v2',
#  '0qBcTg4PmHw2UbUjAonetS',
#  '73o8STNeNy5WwEfTpx6ZAV',
#  '5ZONCg4E4Hp3QIwlUiGasX',
#  '12G1TYIfbpvC0mdFFn4Pbg',
#  '3f43wjAoXDHj1VFSwmd8yV',
#  '67SnNGW8kH366XFFk7NmBj',
#  '5HQ1Y5PN8LaSC22ZMV8vwM',
#  '6KYqqgHpW0qEx54VOCncNL',
#  '38JiIXguTCjbufUUt2nWXy',
#  '02ukIKvNjaiU3qKQ9Zz0n1',
#  '33EvfEwe9JrbEt0PP1lIbt',
#  '3CegiqcSMdRO8Acm2iplpx',
#  '3sZyQTk1DKnTKQ65r3Ah81',
#  '2HoDr1yVksl19omOhc1zWy',
#  '3Ngi0BiTXP2WPpyBFN98sP',
#  '5RGXoZt1qxmAErdhbyKJKq',
#  '0c3iW7RYsVpzZadvHhHvBD',
#  '7tXogifJ5Pn9bGHFjFZ4jQ',
#  '4y9HdSyFG4Kdb7ivFsMUAg',
#  '3EnZoxKtVuh9cXMMQgZyhR',
#  '1Y16xPXK2lGk6dDiMZN95x',
#  '7J2sLvlmDnkoZmHeRa7FeU',
#  '1L7Q6gQQ21PKcxqenJi8Se',
#  '4cnw9b1CCGTHjkREMKrLRL',
#  '15joiMls8SpP1VtGivYh6i',
#  '0Pi5L0sigABLLGr1eNe233',
#  '5M5QXlxqa6Ps6QuprPIWRl',
#  '0CJVU3ZLw3M2Y6IugyjH62',
#  '2037Ob3nwf6lnMCByEoTSB',
#  '6SI4JD7iyQ0rrudhCNtMv0',
#  '5XLC8xoqyua4U7wJiZAWik',
#  '4ik2p5hz9imqkMNa3jXGSn',
#  '2BMRUAA1oTc7e9JPlr6xbZ',
#  '2wjJrxQMrQ7thWQQ62NmV8',
#  '3sFlZWKWLfJ5Uw5p4CyRns',
#  '64eKskmFjeigjskuPpmBGN',
#  '135lkyQRwFlWfmHjJTxtld',
#  '33ZXjLCpiINn8eQIDYEPTD',
#  '3qRPc4QpHGNwKFAzCdqwxA',
#  '4Y2h8WSKDYdBIxPFhPlYqi',
#  '0zkE78jc1kjLXrTYd9ZxpO',
#  '27mgDrExPa3obPAYXd3yQg',
#  '0AFxQBihcXLnNZ5QHPZSJ9',
#  '0hW72l6tZgSY7Od2OUVDIC',
#  '5zkMLiZLve4jFLGyqoKFMt',
#  '6vuYXvA0RTP8MOcJV2yYAN',
#  '37s7AUZKyxO8Xttz7xQLvk',
#  '6MQSM0cJMenB3LnHK5u6nu',
#  '6BdYOvKVbLsNFg674QJbRF',
#  '0LFcFGLYTX6UmeIdO7NVd7',
#  '4hjxVY7QYNDmOclMny7hVY',
#  '5MnXRG5LzgSzdpIkg5nagT',
#  '4S80GOQ96HPsjI1OQU0yl7',
#  '4WvWg9Wzeknes6hSu0tGL1',
#  '1AHfovSnGPVYKaahRtA0U6',
#  '1IpKG8sgrTkrxXPJQOiGIU',
#  '3d55Tng6iYA2M19taXnFq7',
#  '6aTgvValaXNB0IaJHIPLMM',
#  '2fpzSINgTCbf4sS7LH39G5',
#  '329ZgIFH3PVqiUjEnwApBP',
#  '2vdUVX58YIYBqMIHegBLCc',
#  '0Thqjtu54vKMP06pwZkAWp',
#  '6sZv0ECT8cEW3oZtoCuVg4',
#  '0eK5y1c7WDyWwx6k9SFjbT',
#  '0TBzphxYIeDLP9DAJUSUbP',
#  '1F4lm7DxvpNvXfT3cGuJCb',
#  '3kZJlhxS3M3qwRTyzcwuhT',
#  '0F39csm488RSTo3e2QxTf1',
#  '4EQkcrSLF3QdlwNca7sMXY',
#  '4mrR64jwacrmiZluhBelDB',
#  '0dyWQoMOU9oERL6c9vxtRp',
#  '1ZyZBoTB80BYCwHj56eyub',
#  '62q0wyC0YQnQFvaD8mLEbK',
#  '3ITllZnlwkuOef3rt01jn1',
#  '6nJyg6asDkAqfJNSbKaW9z',
#  '2n5iZW75RPN83Bdb5c9D93',
#  '7gKgd0P3dAAePiSQQBqrlf',
#  '7GQU2ONiftn9FIYczNtfgx',
#  '0Qr9Dl5b43RAZuXTSqzBzu',
#  '6dLhl7Jat4JqaKaJlyUy53',
#  '6s4kWgzQwsueo3mfllY1s6',
#  '5eGEc27nnhtmcOh6RC890a',
#  '18ohWhzbMCynq5QJ68ifkW',
#  '2MEvYNn2tRvFDAucAtAKVq',
#  '5KUiLOgwUB2Y8dzTBv8j7R',
#  '4rLsbV5mXnwyn5JWpmHoys',
#  '5EWWCzpA6D8UTRbVQbScp6',
#  '7xXy5wG7nUXwCz6zrnwiTI',
#  '3QLZoic0VvL2b32xaQ80xw',
#  '4pLM9l6X8Wiozu5tr6vZOf',
#  '38aGhG0KaU7m5K1OTH62aM',
#  '6dqE95KU5yVcqDkgEt3TIm',
#  '65EZ286Mq5YZDPm1PF0JC5',
#  '5fFptnb75JZltrujkf3msm',
#  '1f58xau99Rdn0hhcJTwRhz',
#  '6rhZBECdmfFpeKQe5z77fC',
#  '0eJzykWzPq1TW7hrvMxKc9',
#  '5H3B1WtZYGmyOYOXgQltKU',
#  '4NuXgp5pMahLoNF7h21hxt',
#  '7sLpSWxQazJzDVG6YGzlVs',
#  '2TgPHDU8zPgAvkSLXkHKXR',
#  '2jKoVlU7VAmExKJ1Jh3w9P',
#  '1jvguq5D51AOcxX1jiOsMa',
#  '0JlYNNkFTSuvlkSXcyPHHP',
#  '4QS50XnspJ1QCcHMjh3Q8S',
#  '6QZZAdLvmRKCKeWCeocsQV',
#  '4F8rYEoiBjPaRgQXLVtN5a',
#  '51ehwRYBLHsF79TQGH7tIf',
#  '666HYUUijpHmbVjOEr6VTK',
#  '3YNm3yDaCqAxLQLR8CHpof',
#  '2QO08YEDSNQI72PiH0hgRQ',
#  '19gEmPjfqSZT0ulDRfjl0m',
#  '11snoo75iZ4fMc3pIeyVtK',
#  '4KxiDMQBLiHZ0efSyvVsKc',
#  '05v6w9fcXfhRjdcV3MxHFG',
#  '1YAVE0ASZIwA7W5zjtwSOj',
#  '5V6joRdSea6gGlvycKrcJ4',
#  '4P0ENsgTwxTqEyNUIk0sqm',
#  '5NUGH4LvLAZCFmPIZlhOk9',
#  '3vm7NBtMNULBDQ8yAwVoWC',
#  '4sMH75ctV0RVSOHZqXJpHD',
#  '2AP0eyajGi0rbnMvf1UyKP',
#  '1T1n12EX3AONbqwlAyr6iN',
#  '5zIk4pDMxSh7yKotDgFwTK',
#  '4fGgwnXxWD3J1fMhFEGmah',
#  '2mehHNForRahnPueLQAgfv',
#  '3qA9K2uI9v3lxq9ZFFtOmN',
#  '7ngdkrVQPgP3AoIxUrTpHT',
#  '5Vyw16U5k4bpGaRqfzyyMo',
#  '54hFBqrtiWfrh5WQJZwguj',
#  '1oLJS489FjEmce4qzDolcb',
#  '0e4IXw3AYaZSBC5kIAbAp1',
#  '0Db1a7sL9MOjXgO5Z7zRM4',
#  '4jbLPR6XBNA5gDGtZij0xa',
#  '5NjzlZhX7LjEPHPs1ZInUC',
#  '0eIi74W5kKmmcP57CHLRwf',
#  '0JE96aGlmdoyeyIspU6fgk',
#  '63chU4uELCWpJiPspSMtHy',
#  '20ZubgobJ4AeBg70OhGENM',
#  '0QCZXqxsGoGN6ApLHiobZf',
#  '2JPfvvwIYz49JHZhUl87YU',
#  '0S0dUSa9p9yhaNpZDCAkKY',
#  '4TvxDMTOkbK2yt7IfHWqZQ',
#  '1uXr1bnQtyNgvUSbqEJjcy',
#  '0PV1TFUMTBrDETzW6KQulB',
#  '1UxQ8VEi0uMa8eLNpSmQnw',
#  '7C6LiDgE7ro2R8A7WFQ8kv',
#  '6ZK357j22DuGv2O7z0GRbA',
#  '7nh0HBrSbnmCfAraHcg7vK',
#  '5SkRLpaGtvYPhw02vZhQQ9',
#  '5g1vtHqi9uV7xtYeCcFOBx',
#  '4OAwM66Hv5pXQwVitznokW',
#  '3umzgdtcxYnNftYi76fuRP',
#  '1xZkUoGk21z8Qfw2L88fpV',
#  '1VB1t9yQJFzSTGZLaQhAKZ',
#  '5dZ5zZfUHRVsa134BJ9ngx',
#  '7LH65o2WUgYY1SRxYzirES',
#  '74sP5mKCxxHePieT1rW7ct',
#  '3FoQTbLa3k0fifyrZDfF8q',
#  '6EQ4orawx8eo0aXH0pOKLE',
#  '6dkdyqj9E2rDBfwd9IHNBB',
#  '2K3LkuueAqc2FrpN6FFZtR',
#  '6j8lAie0mdUNreql5d5Ejz',
#  '4Li2WHPkuyCdtmokzW2007',
#  '06UPCXzhIsXnceSXmKLMEY',
#  '1unbLw4cvR8za4YpHFWcN7',
#  '1BR5vhAlaoUiijQ28p6jlN',
#  '5GzKIbJyrV6rUakLyezNwn',
#  '49R8nxL8K4zvEI1LxvhLMx',
#  '6ygSlFgsuHPLENIKP860Hg',
#  '79XrkTOfV1AqySNjVlygpW',
#  '4PZ1FyZW38n1aQDEU4YLDT',
#  '3GZD6HmiNUhxXYf8Gch723',
#  '3gY6tiCNsuVi6s8kPV6aQg',
#  '1MVbzSQHqQ4XGN7TV0WcrH',
#  '4Cg05r39aFjzN1UN9jTK4O',
#  '2liSUqqOmcwBd1p0euASJy',
#  '65rRB2mspD309xE6YimZTl',
#  '5QD28FqaM3jTfsqWwvRZwv',
#  '0S6Qv027k2cVgEKrnuYkwI',
#  '2XEDvwzY9TymhYPqi2y0GL',
#  '5QluxyMLe9F8P4VsdB7Jbh',
#  '6RmZeNIllP0fxpSF5bNjrW',
#  '7zQHDVzyoutqk3Ed0iduDv',
#  '0eagpFgYdVP8oF7jfrrKxQ',
#  '35yBFG30bZoWvcRBfFWgJD',
#  '1Z7C8ClE8UEaH70jCCeJH2',
#  '2LvRR121MWFmmEGkuV2vQP',
#  '23Cx5Jv0bsCMoUnoygy5jy',
#  '5CiVeMl88CnbJbRAHMU6xG',
#  '0NEqNYf1mcLUcXqyWXEfSx',
#  '2fT9Y3qHsuUzsE1Z8MErCj',
#  '5jchyJ5MquFoIzHbtNaqoW',
#  '1gIa5W0AhvgfKgCu2RNR8C',
#  '72DuDVv06ZtKDceAlq40f2',
#  '4ezafcOuI5em8LoE2xxnpv',
#  '24poDm4fvzXqt74loxSKdn',
#  '33v3li2O3fd0imDIOZxFqt',
#  '1vJc5ntrmTk0f9MhqCUx13',
#  '6NJGiaHHtKx1vIO0TVjnuD',
#  '2cZuNzaAGNFozlZTxSDU1g',
#  '7f6gNYtaXuEFanKOJxeXS0',
#  '6eAIynPK19mHRypXB26o6X',
#  '7zTZ7D5NSfY5YMMC9blIGX',
#  '6vAIPNu2wFVQRvHJFFzmly',
#  '4vhPt5YcFZSxmG63cYQ0ne',
#  '5rdoJb9eXg4Hh2sYDg5pHV',
#  '4qlwlTd2lPWyPFktn0TXST',
#  '3lPqzfO2YHhjwlkVf7OKLY',
#  '27GmP9AWRs744SzKcpJsTZ',
#  '31bf9SEOppLU6lQ85d8om6',
#  '1MxAxn1jme5dT4ByQq8LLi',
#  '5DW8XTNmAVvKxTO3zj8qCB',
#  '7dltD9eEX7X1zk8JJ9BS0e',
#  '4k26Z0ncaGQ6JisQblsCom',
#  '09wQdd0JQbkp9yKfRfwhjG',
#  '56Tci8VFMXjEAx6pCqVbP3',
#  '0ed6evAMZvewGh4UI9KkVU',
#  '7996f9NZeypc4jqfc6hJUa',
#  '6F7G2URdiV501r4FsI4g9c',
#  '1lnqjCZfobpQe6DXURSvzn',
#  '3c3rrsekW7AqD9ZSaV26sD',
#  '3UK1O6wIWUVIHisqCJkilS',
#  '3ohEnp1lxT3MWZfcT4S0qs',
#  '3IXsOL4PsctxqiWohSYthI',
#  '0fvbf2vSsnusAEBoTR84Hn',
#  '6sf35vqrEAN8fOFzrKmv9A',
#  '3iZKQU7zgHw2tFuqD7mdqL',
#  '5EiWb5C23RXPdD6uIlYMUg',
#  '1EfJ3dY940sCY9DbgxZIPI',
#  '7qFEFcjmSAtODGtLYqraCq',
#  '6NenX8oihDhKJPQlMbJN8b',
#  '128vB8Ow71KEquIiUv1JMZ',
#  '5hvXJDTpVjsnp80f5Q8WAG',
#  '5ANJnOZSespzNYyXnekRdi',
#  '6vmYIyS1CImTs6ooYiwbBn',
#  '5Nz1U7drupMgIhM4qHK8kr',
#  '6GGTHtl3cVU8ZMygVoHgTd',
#  '3bRl0nT7kGwA9dtoKwdbUt',
#  '4GGbJ60q5HIN8wKOp9Xabz',
#  '2217fjGdGIdPpZ0zeo4z8r',
#  '6iaXP51tRc5gBWmESaI85u',
#  '1tQwSdSEhAaq7VzYZZDtAt',
#  '5NmL2zxnlt9GiTB2TQbvFM',
#  '1mY9YGuaRWwE92vkgKKhp9',
#  '2lEuz5U4338FPZ3kh1hThb',
#  '25ZnLelhEKRwcsP7ycTEgb',
#  '0qaCLJ18R2o17WiXoFI0tr',
#  '0UNRwrbkIGoavCNy7ZY2QB',
#  '5LRbfATo59n0jGtCDoA5fT',
#  '0301nLjG0ti26rx5ZmfqtP',
#  '0s9COZY8wLOadAzbHka2GO',
#  '2diwSapHe5uPoKoCYZWLpl',
#  '1TLLDzB9uA1fpX9JWvGquQ',
#  '158DIbrVt4YbqNnWyRCS3P',
#  '2eK3hXbKG2uhn9XNsgTHqM',
#  '5CE1jL4dkfZlX5CiHZh5ap',
#  '6glsMWIMIxQ4BedzLqGVi4',
#  '0Bb21NEv7yjSJ8ro2k2SZC',
#  '1FRwED5t5bdM9lI9bOPoBD',
#  '24ZY0awQOi5BjkPVSAfbu0',
#  '3gTuBlAaWRgOfjZSy3TeDW',
#  '7MkX07TjBPtPZHnBqJkCuY',
#  '4laFshzjUXnfgtK8qTMaOO',
#  '6YYd5MLpu45J0uLrMdivF7',
#  '0e7S689mFbBnIWTWtjc4b4',
#  '0qxe9OX0etknFMWslnAvsV',
#  '1KXpyjHZgLH7zo9D0XZ25U',
#  '4Fjs6tGrb52bobu6mPhOyh',
#  '0OzsN17s9jhYWfHJtSf6Zs',
#  '0AN7KIF9qkbzk2p2tG7jPE',
#  '6vhT2ZV2KdFkQUX7P7MhL7',
#  '55VdmFIyzDN6HBmUYshZKK',
#  '3iZc0giQC5ySLgbJ6gQFEl',
#  '7I36ra1sLzZPKTRKg3pvSW',
#  '5WwGFUPLWz6t7jROXn6j4M',
#  '6E5JDnaSWqj7G0eVUiUjjh',
#  '6MMuI4k4Vs5ghtDH5i2hBg',
#  '3B1JDk8d3vTixQL1oq07ve',
#  '1susySjUPhuQwze0W0p1nA',
#  '1rWlUL9TkC5spjbBKPkrvk',
#  '5hHCQ0jbaBDiE5fIKzYf7W',
#  '2hkTbtEU8qWJEAV45hJ0yg',
#  '7kTgnCkQFP74Vp7EJPUjL5',
#  '7MEogliLuUdO6LqkXOw8w2',
#  '1lqRqqZMpYCku3hCvKwP8g',
#  '5fgO1p86cwU8llccdFXZTI',
#  '4VZPYvMTByQytb6F3MKP4w',
#  '7qPxFNlgsqFz5fEW3LaQfr',
#  '6VGLVAMNx79ZYz2iwgitxF',
#  '0W5M10Od3wY9GnS3MVa8x7',
#  '5YpZh8wfS4moRBk0ijNcXr',
#  '3jdh7YQBCxykbhL7z0Ehu5',
#  '495Q6u62JDHAdkVYF5JySp',
#  '2wVaikw9WmhmIPyNt6BWa2',
#  '5h9xsuz0xd0rvNq2TCUjaq',
#  '0XqPKnwz4hIcSRz7cqOZQ4',
#  '1mxXB3Vsaaw9goChMrQuiK',
#  '0D21XvHcVsIvJM6FcGY2BT',
#  '1fl37k9gyIaETW0nSGf7nn',
#  '5mUL84pTkvpDFL5BQ8xGnv',
#  '56whVbEPZ2bRA5VboQPned',
#  '72Kt1fy9LGyTkxWlfV3b5J',
#  '62iT1nKQzhNPOlZM8CtjpW',
#  '4ZYKaPmduDTry3Km1wuVEo',
#  '1fQFC018fCafNhHbN4CNoO',
#  '5X6J2NlFuXZfmpze7XO83h',
#  '5SScFmMvQqlvQrM8vvhZnx',
#  '5H4PU7wBIXL259apGjSpOr',
#  '1iQ5E4z6CJ38dIzvMI9Wdo',
#  '5fpizYGbi5IQoEraj6FP0R',
#  '4cFsDgicbYDZTmlJjkv4qC',
#  '5mEwhCsqadBZIE7SSrv1gC',
#  '667CkwNvTozFtCMDC7BfBU',
#  '5hALSggfcyvBNLUHY8pvZd',
#  '4tSIgIuZ6qkYKjHvf6sZAq',
#  '5UsLjwBaTHBX4ektWIr4XX',
#  '5xPzHwAHfKhYiAiwKwBi2B',
#  '0T2AYQdV9KRC8y8FC1jKq4',
#  '6Bx4dIR9O0QcS8Or05rMG2',
#  '503OTo2dSqe7qk76rgsbep',
#  '70RMVzexrIvYJiFEnuGymb',
#  '0b3BzRzyKDxINqf1cl6G5W',
#  '5rurZZeggozpAZIHbI55cm',
#  '10u965HliXlz7MfeH0U0MD',
#  '0Gv6sr4tFPkYDIuUVxOx7H',
#  '6TE2eFTDmfYOj3DpeQV5lD',
#  '5jRPgUmIGGbRVYIo0l0AxM',
#  '6Wnlq1Pu3I0BajLvxn05Vr',
#  '1mavQ4WCzXSeL2Dm5DS4GQ',
#  '2vfvGlqCB7oertO5VLE0sz',
#  '7fuoqve1SOEBmhc2PoQTF0',
#  '2QFgSYozXaVP6SgXz26I7O',
#  '16LnNR25rqcvQVNv5UEQ7g',
#  '0rkzHjL6NnDnRic4qccG12',
#  '5YEOzOojehCqxGQCcQiyR4',
#  '7zDrWCJoubEqoMleqHKohh',
#  '5oEgPvhTZ4CFjeuuLfmMsI',
#  '34oJGwpYsd3InHUDx0fbwx',
#  '21JGjoekHtVwUfbQsFdQRX',
#  '5SZzTVEEYwpLa9nlOV0P53',
#  '20oenBXlmwIfK0F3fQIjhM',
#  '3lngFMm1QkSaHeAr8eAPzd',
#  '0TCXBtR33qJs3EQFEpsxSP',
#  '1wYp8ISMvX8qrflPrBU9Yo',
#  '77TbvqpcGHONJJxswoFFWx',
#  '6fmFt6Tg6gXQBpmjbuYfZ3',
#  '7wt6sMZ7RVmb4fiFXePS3K',
#  '2AYIdIi4999ehmvEvl2PDw',
#  '4F3AZKEJubvPsl0hBArVBW',
#  '6v4s7JosY38tu0hTZGpgrx',
#  '5gPRPgUkw1HjtBzlMR2H1S',
#  '2SAZQuvKFKbYxUJ3iKkU6X',
#  '3xI2BX87nRys1ENw1Zl0El',
#  '26sfR6xBMYUQ9ORoopLphT',
#  '28j3OCjlPCyyYw2dtttxVG',
#  '2evqSTFeM6yuBj3vfc93Kz',
#  '3gY58bNYRaVuMYvnDFOnIg',
#  '6HZILIRieu8S0iqY8kIKhj',
#  '47JeI0gw7h93O7etXl6s4L',
#  '6CqH2Xvbu78tgoT5450fYC',
#  '2LKKLkOP9dRDXO3yFWhqYG',
#  '1RPhSs2lDYKjDsELKtPvQd',
#  '0Z2J91b2iTGLVTZC4fKgxf',
#  '0SlljMy4uEgoVPCyavtcHH',
#  '6RkzSFjZsalFmc4R0IwPF6',
#  '1iAf7OlnMTUo2EnE6QP4CR',
#  '1L3XtD01wmvvmsBYp83DHo',
#  '2nzFiCB8YoXf24MAM1qDmU',
#  '3WXNzlFDSfjEmNFUOSccf7',
#  '3LHbk7L7mFQj0Wiv4dB9lR',
#  '5m1l2O038zHvOiwaVkTter',
#  '0UzHuhWai0Vy45c60ZBfwl',
#  '2lMg3lCMOGistaWBNGjuT3',
#  '0VgkVdmE4gld66l8iyGjgx',
#  '72UCHNyJcymw81x0AKevho',
#  '1xIxMz1sNQ4b6svH1GuTtF',
#  '1FkgoPdajl8gwC1hlyvHtC',
#  '01xhMrdCefADl7HSttJaf7',
#  '66Exwk617LAM1nk3fJflZq',
#  '4v193RqG4FcQYh2QTV5ger',
#  '7B7Bzbl3gI1GrnCatsDh4X',
#  '6e7n5KKbHZppGDSh4bQqsP',
#  '7Ge0AVW2Wz5xRUkXzguw4b',
#  '4kcA8W5BCpdghKMy02RVn0',
#  '211ZgvK09nFK4bLRKf1NtQ',
#  '0oPKi455b9ejRX7NCrYHju',
#  '6xCZ5hulrqJwPb4CPK4e7G',
#  '4yCoKbBF1JGTFhOkVk2cx1',
#  '4GfhaqyXVJVRvwfC4NKlHB',
#  '05jNrrouvvb07kGZ75ML2q',
#  '6Hr77eZSmaVGgH0vVulMUH',
#  '2fClGossFdEdhjjeYceaN7',
#  '2y11kj62twTSGUf6Efu2Gy',
#  '3umkfREv66uoqKndZlgwrP',
#  '44fKMsjVGvJSmsRiPDSBfE',
#  '7p8ra6S3cgpoIluFUDTr9V',
#  '1hxwGDei6E7DkUoPP4ZNLu',
#  '5doZkFeiG7g5EXpUH36B6B',
#  '7rzbAd8dsYRt2fPcxhPf92',
#  '0FvHLZpMCfyCSjAFzQlpbI',
#  '0Me7PKWWe4H03MslQ8hXtd',
#  '2UuVMrfvwxtm0qvlWpht1R',
#  '7cvRqcXNijtuGI0AqLvaoB',
#  '736y1ZQptSw5iaMkbmvu9X',
#  '6UTvqqPGNml0Mj0i5U0KMn',
#  '4zoYSZrDb3EUPWlDi2OwAC',
#  '56jrr4tOIjaxdMCJwKnmDB',
#  '08azaGQ1YKWvajMDARPSeZ',
#  '0MvqSYPr5Wi62JB7VWvqwz',
#  '4qI5DVg0MqKIGF07A7va7R',
#  '4dORXYAPF8uXC5VQmYCLVM',
#  '2KYaNwbx28dNrZUqtiJiX1',
#  '0I3q5fE6wg7LIfHGngUTnV',
#  '0brst8Eu2TRY13cwTQMcQc',
#  '62SqHqTAndm0pqZ8oVvlkb',
#  '5k7wy2Ek7y6kSQ4fER7w0E',
#  '29e2gdZN35wxeGgDtkXjIa',
#  '3k6Y1ESBwF1low4hHsY4wu',
#  '03DxO8kGNrEGr1VjPSdQs2',
#  '60lUecrFeE2t6QMJ1Nmsve',
#  '7AbLGIOzFkx6jHq5en5xiH',
#  '0C8RxBixBaXYc5enAXIm28',
#  '2Li9UJop1djc8aH4MjuJUX',
#  '5FNrbC6EKv4HXqz5MOPZm7',
#  '7rhsXamb92uzkfHG3s9Ziz',
#  '1lBQnp2hUBZuyvMaNTslRQ',
#  '1IqNlIUJivQXXSp6MgCwRl',
#  '4wm0t8wbrXBvEu0txtvapv',
#  '1xspOMs469p7NKQJVHlj24',
#  '1Gm3jwEy0cx0souTcRGEby',
#  '6snzF7H4IdyuKi96TxMtbd',
#  '4mnjwMLCk3JZkhkok3u5g1',
#  '2Cqr74oA90iffydKmgjwhp',
#  '3M214U0mwSm041GsQR3nrO',
#  '30uCmqegKQnH5AbOE51gPD',
#  '3s44Qv8x974tm0ueLexMWN',
#  '4JlOPpMwwZTfT0wDsuBBOc',
#  '26rvZvXZsbizgU7hsO9zN8',
#  '1MWadNloePMahSZqi0fN9Y',
#  '59WN2psjkt1tyaxjspN8fp',
#  '4LtLbmRErvtrNrYR6gbhh7',
#  '575NJxNUVDqwJGdzBrlLbv',
#  '5wrDrajYZSJqta7rJBvcJV',
#  '2P91MQbaiQOfbiz9VqhqKQ',
#  '5IVuqXILoxVWvWEPm82Jxr',
#  '6y2Kaz9QI01XBKJ8mTb7Pf',
#  '2M9ULmQwTaTGmAdXaXpfz5',
#  '4vjpLMyL3ZO6aphdYr8XYw',
#  '5masKPHeAOVNgxdLebIcK7',
#  '2DYG3OdXCbxdocQeoYJGDc',
#  '5kApwSRDqF5CKclVLw1FBM',
#  '152lZdxL1OR0ZMW6KquMif',
#  '10bt2wAkFgCWRCEOyAyWT9',
#  '2qPUnoasNe4Ep43emVXEig',
#  '0yvPEnB032fojLfVluFjUv',
#  '6RX5iL93VZ5fKmyvNXvF1r',
#  '3sjn3DcHbwMnHfheOH73Ym',
#  '3QGsuHI8jO1Rx4JWLUh9jd',
#  '2igwFfvr1OAGX9SKDCPBwO',
#  '44ONERBHALxftQNWq6dmyd',
#  '1SJtlNRJDeYHioymcvsqev',
#  '55S2PQgSMYAhgoTCcGCDfw',
#  '0GiwV6v3AgJfdu59tj719Y',
#  '3H7ihDc1dqLriiWXwsc2po',
#  '4RxzgZMbYLLnLYaW00Wv4q',
#  '7m9OqQk4RVRkw9JJdeAw96',
#  '6U4VqEHy4n5VeiH4pQPL24',
#  '0C6BYlsXKgAQPnMfbYOnV4',
#  '1SC5rEoYDGUK4NfG82494W',
#  '1riPE3NCV1OBmSXqpYiMJY',
#  '55CHeLEfn5iJ0IIkgaa4si',
#  '1jaTQ3nqY3oAAYyCTbIvnM',
#  '6nxcOGl5E292RUh7iR7KTW',
#  '5OxveXfvga2t0se21d96Ow',
#  '0wQL4dv6dQjuiGdmJIjRCu',
#  '3nY8AqaMNNHHLYV4380ol0',
#  '4N4jm2vBlLxKDLFDmIj69p',
#  '4H4J97MRsuEVdhE9RxOPxk',
#  '2kwt2rsc4VbZc7cHEpblIs',
#  '5AyL2kgLtTWEu3qO3B9SqK',
#  '61te57XnqBBQ3HSGHT3SQx',
#  '7MXVkk9YMctZqd1Srtv4MB',
#  '5u1n1kITHCxxp8twBcZxWy',
#  '0bbM9yJYKSi8PSubMQaUYu',
#  '1cS0TgbR263ey9jn0MwD2s',
#  '2Zg0aB5oVQlbQE1vzQmIIY',
#  '2iUXsYOEPhVqEBwsqP70rE',
#  '11VApNQCWLJdzxWrlmwzUa',
#  '58zsLZPvfflaiIbNWoA22O',
#  '1Jz1yhcPm1Yt6aoed3zact',
#  '4Oun2ylbjFKMPTiaSbbCih',
#  '5F469F5Dk2Zzm6BpP0OhVq',
#  '0d2iYfpKoM0QCKvcLCkBao',
#  '275765DrtmWP29V5kVzU9g',
#  '0e8nrvls4Qqv5Rfa2UhqmO',
#  '1UZ25gykR30Oewh3dBRtVZ',
#  '3pndPhlQWjuSoXhcIIdBjv',
#  '0Fv5N0cHBsl4bzCbollCAS',
#  '4HW5kSQ8M2IQWZhSxERvla',
#  '78QR3Wp35dqAhFEc2qAGjE',
#  '2xLMifQCjDGFmkHkpNLD9h',
#  '4S8d14HvHb70ImctNgVzQQ',
#  '798nzni0JSUWMVJJBCYYF1',
#  '1M6SuEJZJkZf2S419vIPkB',
#  '6vN77lE9LK6HP2DewaN6HZ',
#  '2UVbBKQOdFAekPTRsnkzcf',
#  '5Nu1cp2yi4TlZF4KTmElFD',
#  '3QHPHLAkYV5cQBUYs6rowx',
#  '5D2mYZuzcgjpchVY1pmTPh',
#  '6IaieqiCVvsNvEt6Y7yOFa',
#  '7xHWNBFm6ObGEQPaUxHuKO',
#  '5WvAo7DNuPRmk4APhdPzi8',
#  '0Y4hwUppbGc8aIBmiTz30A',
#  '51rXHuKN8Loc4sUlKPODgH',
#  '6tarvNiKnEjYMj1VZhlDqR',
#  '75Q69chmd8CEZbVsA4CDMm',
#  '6DB2KOEwHnjkgEnBt5SdeJ',
#  '0TBgMKD86t1VP3IzhxCoUl',
#  '2zRR41MU5nXB1LeBkyjgtV',
#  '2EEeOnHehOozLq4aS0n6SL',
#  '5hTpBe8h35rJ67eAWHQsJx',
#  '6fTdcGsjxlAD9PSkoPaLMX',
#  '1rkfJLgTlB6XYNjgZ0sVaK',
#  '0M9ydKzuF3oZTfYYPfaGX1',
#  '4dVpf9jZjcORqGTLUaeYj9',
#  '0Fpen1PTuEnCmOJtUU9Iud',
#  '0ZNrc4kNeQYD9koZ3KvCsy',
#  '2qcG0nZ6S3zZV0UrkY5nFo',
#  '3ZLyt2ndLFBh148XRYjYYZ',
#  '6qMXubogFdMrvVMJwqATzd',
#  '0jx8zY5JQsS4YEQcfkoc5C',
#  '22UDw8rSfLbUsaAGTXQ4Z8',
#  '2bjwRfXMk4uRgOD9IBYl9h',
#  '343YBumqHu19cGoGARUTsd',
#  '2GGMabyHXnJmjY6CXhhB2e',
#  '0utlOiJy2weVl9WTkcEWHy',
#  '0hYwohkL9Hd6zQAJoOtBLa',
#  '7GX5flRQZVHRAGd6B4TmDO',
#  '1CAijerspiGnyZHAVsGNL1',
#  '5274I4mUMnYczyeXkGDWZN',
#  '79esEXlqqmq0GPz0xQSZTV',
#  '6gzIcEUuswJQGfJNPYMjjv',
#  '2ySRRtrAwDUF4FipiF1Djt',
#  '3edzl4zvKFi0D3iuF6cs2f',
#  '1wcaN0MSG6KQ43UNjpRvid',
#  '5LgA1OLvaJ5chQyjtn5RQu',
#  '7floNISpH8VF4z4459Qo18',
#  '1B87ZDrD3Pno9hS4stamWO',
#  '275a9yzwGB6ncAW4SxY7q3',
#  '20jYtEun4dUdYZ9foaOC48',
#  '6CjtS2JZH9RkDz5UVInsa9',
#  '2JvzF1RMd7lE3KmFlsyZD8',
#  '3qN5qMTKyEEmiTZD38BNTT',
#  '1wJRveJZLSb1rjhnUHQiv6',
#  '1WSGTYKLEpKfNQYYW5Oymt',
#  '2eNWfN0pJIC5azoGAiuiGo',
#  '2U5cq89GCnsR1yixKkC8d5',
#  '10Igtw8bSDyyFs7KIsKngZ',
#  '1qsHYUd2c1wFGcn7e63QmG',
#  '3U21A07gAloCc4P7J8rxcn',
#  '3s7MCdXyWmwjdcWh7GWXas',
#  '1Bqxj0aH5KewYHKUg1IdrF',
#  '3M6gRDCudfKsT1mG13Tnmx',
#  '5A1w94uzc1kO1Zhe8WWxC3',
#  '27PmvZoffODNFW2p7ehZTQ',
#  '5Qy6a5KzM4XlRxsNcGYhgH',
#  '2QrXzOqLCVDRZHkToA0tSR',
#  '05t7JMip6JrLuSrMV5yYjX',
#  '3hsmbFKT5Cujb5GQjqEU39',
#  '0KfgfxTnqfX4IfhVDpPYTd',
#  '5203pcq3cNteJuOVhIEnt6',
#  '4ENY2LAaJFqHwNnDRaRvH6',
#  '6p4bSrMneVEWlsgby0t7P8',
#  '59c0QaXXrzFK01jwdvYQms',
#  '6c7LJCOsJm1WsY1rmjW1ba',
#  '3TIamUcqN1kqYkXeTCq1Y5',
#  '1geQaiy3LVKZdAFQPZdbzY',
#  '71BaduW82YgwVsBurqczGr',
#  '404rp6LygftuwFGjKuom6B',
#  '3QWk9jUYrxkKmM6luMRARv',
#  '0q2n4kmbSaQUPfECkNpkfD',
#  '5nzhL67GpF9szXWg5y509A',
#  '5uZm7EFtP5aoTJvx5gv9Xf',
#  '2ZltjIqztEpZtafc8w0I9t',
#  '2Fxmhks0bxGSBdJ92vM42m',
#  '1jkEorRvoRQNo1WZfD1X5q',
#  '3QMUV6S5vaTvZjjSslrOZd',
#  '1Z4UKak2eNteHFZkwiYPNz',
#  '7LptQZjp5wgdYDQZPjOV9O',
#  '4gH4e5ENzVDg4N8fOp2vDP',
#  '2bjUEg4jBtKBlPdNrTAppI',
#  '6axvnGwB3rtoriGI1lPhTz',
#  '1lOe9qE0vR9zwWQAOk6CoO',
#  '2gwkD6igEhQbDQegRCcdoB',
#  '0IUgswE9wJaY4QIQZEDTKe',
#  '6uFn47ACjqYkc0jADwEdj1',
#  '3yNZ5r3LKfdmjoS3gkhUCT',
#  '4RMqA9GixWNB7H6coZFXJN',
#  '7oqftogUN82Q7VNy2TmTJW',
#  '0Ryd8975WihbObpp5cPW1t',
#  '4e0FYxSROat25pH16zMTZI',
#  '2Eb367lyxqaHt6sLNANyrr',
#  '6cjSh516BbrNUs213jDAGm',
#  '5PTG6rrL6EPFD9E2QMI2pl',
#  '0Xek5rqai2jcOWCYWJfVCF',
#  '124NFj84ppZ5pAxTuVQYCQ',
#  '3AMnOVxEHUgVrythGgqPhI',
#  '67cpn8ZBO7QU67jky8Fh47',
#  '4hanO6Du5J7QEguNHYZHmw',
#  '0sVcnEo2jnUnr3p7uVDZ9o',
#  '2xKQj6P0TgxBVaRiojP2s2',
#  '6G7r3yTCXVl1lXmFSkzEYB',
#  '1KIQ0RscHwxXPJUvhuO5Bl',
#  '67xBtV07CC73eFw7z5oCvU',
#  '3KkWGDCb6byHjNYjxBihGK',
#  '2nKYHpmwjLaEOXS3o7QMiz',
#  '3WyRgi8CzQnhzO0xw79tTS',
#  '5rU6kDNXZLXIinFezpbWbO',
#  '0fySG6A6qLE8IvDpayb5bM',
#  '4sjiIpEv617LDXaidKioOI',
#  '5Z8HZM6iQMhhqyPcCGY5g9',
#  '67XyC1GdSkKb9sbRRkUDXS',
#  '7gYE3GWQN3Jf6z9J8EEbdy',
#  '00ko9WaS4jOX1kEk3gvHjf',
#  '1xsP6AITcWNigBYBYVnVZw',
#  '0yFvWTLs3iIwDbc91noXGT',
#  '6mzaCRuLTRiz1caGOum3zT',
#  '01GmGxOPy22EdAZGC0X6q1',
#  '333OkWOgbV6C8I5wRLfuSx',
#  '5LWprrbySabBAMm0aE447a',
#  '0XPpkGBVE0QIOGSvW1nMEz',
#  '4LvRT9c5IKxC8GHVPAAaHb',
#  '1CHhAINmT48RpXE5owAo3Q',
#  '2Jv5zlZ7iCZP7K1j26izha',
#  '0QBRshHeQLEThdj2TqxM9n',
#  '37ufe1F2g1nOuI0z2sd6M4',
#  '500qWQEycoFAUVK8ijpD5O',
#  '47UFoOuvrkt4khE7c5aap6',
#  '3950uQm4KQL3ckerKBeXYp',
#  '6IRdLKIyS4p7XNiP8r6rsx',
#  '3PdgIdRXJjgxfOr7slldel',
#  '38TgLPNHsPzgqri5G4SPun',
#  '00B7TZ0Xawar6NZ00JFomN',
#  '498lAnNuuwNqtR3iM0ljBN',
#  '1Y3GQaJTwozTqkmSskgRs1',
#  '0uH6JssU7mWkTT9mqeqEvL',
#  '6NnVtgx8QOFYIKGTMmlNsA',
#  '3nQQotHU6YtE0Z4kiMNoW8',
#  '0Z1nbG2KOuRKntstSAkSox',
#  '735RSTb2xbtWbDtKD9XDYi',
#  '6Gg1gjgKi2AK4e0qzsR7sd',
#  '6Ozh9Ok6h4Oi1wUSLtBseN',
#  '51LIqkda3pTeECZUhMnool',
#  '1jxKaRGjTVsZrefHySL69R',
#  '4SZepBIPDRwPaHIjAKwRDb',
#  '5ravc2aiNoYmu9m37diYXW',
#  '1DVgepjQjFsdAO94zvvwgQ',
#  '2TsD9kSbgYx5fSNRsoNURE',
#  '7nGJygXx3D1lsSt8aAxRcQ',
#  '1ZDmxwg7Lywlx68b7SsJjj',
#  '0BOmhToQ03yOdpzYKMEnAg',
#  '0IFMbLUK5ttPmXyK16qUQu',
#  '7sd72KZS8D59g5NmhxyHpJ',
#  '7LBohG6plAhWaHjuzi4CpY',
#  '6Lme9Ly3CUl6CcHM2AeiQi',
#  '3zxiTHxE4MxwuYf8aLQ9ax',
#  '5BviN9XWqCYE88AOJg6nEK',
#  '2rMAtCaTj16NptyVfEIeAC',
#  '6JsHgIkMYHcbNtKfsal2Mg',
#  '3mBRfojfwsGouVPJHhiVd9',
#  '5HGU08aDQkOjwogqE3SwhG',
#  '4bEcoz1OcfMgUbp2ft8ieQ',
#  '2sssyogPeYk581LqeMZOQu',
#  '5n9O3DqswW3Vm5b3Z07zcB',
#  '3JW5InOE9YuV0CoZ508coD',
#  '4m2KzbRNBgL53fGzfCEPA0',
#  '79s5XnCN4TJKTVMSmOx8Ep',
#  '6bv4WvcUsV2gZXl54d3yst',
#  '56AMYGJzxBO6p8v0wEe9de',
#  '42k9e2hgl98IdgkXLg4pxs',
#  '7ms3VzLTfr7fXNOqA4Mkx9',
#  '40mjsnRjCpycdUw3xhS20g',
#  '02TmyBZCgcVihv9PVK9Mw2',
#  '598yNsG1JFrGd4n2kMoz7F',
#  '3RZftiuTcLOqpsd8ZlwNhr',
#  '7lvBY4IVc4w7bL6HXq8hSo',
#  '3BM2Zv6Sik7KDHb2LP9Z1e',
#  '1ThmUihH9dF8EV08ku5AXN',
#  '2tZf0xZS5H6YXjvlDUnXrD',
#  '7zxRMhXxJMQCeDDg0rKAVo',
#  '7F1LWA9sIlTorHUo4amGqk',
#  '3Tc57t9l2O8FwQZtQOvPXK',
#  '2JF8KwK1hH7MWxKcFdTlcg',
#  '2OaKHGvIxoOzIYjyMsxcT8',
#  '53yWQ1FObrwPlVYCZdR6es',
#  '7fNn46W67PGykZ2ThsiGzU',
#  '4Z7XtjSL1fyFnd6bTYhEIQ',
#  '0iHKUzrBeeIgkFsi4h3SHK',
#  '0BjEQJZy4rfUNpKHiaYirL',
#  '2St8HeG23Nzp4NYaWTNtuM',
#  '0sr5LOMv4x0jmTYfe6oOvP',
#  '311TRQfl3MkFsFOW7iFMzL',
#  '0uYMerBHiIHrCv9FHfzUMe',
#  '2FvD20Z8aoWIePi7PoN8sG',
#  '0Q2n5yzl2XRqYbV77tZNYp',
#  '2VDadIDCFgDqvVCvaDPtn9',
#  '3UnYMo1aeD0o8VtHy3R8cs',
#  '18AIesWCXvIbXu8RqQw1E1',
#  '6cZH4rX1KTt1aJ3Ql6Ynja',
#  '0dIz1I7IwX5ardG47AHxCZ',
#  '7ExiKb3YCTGpaLPtFKzYUk',
#  '5AmzfSxCIOPxPmppoHrr12',
#  '4NY4FeAJyTd0fkkMI0POPn',
#  '5IhS1ig4KRhO4TXH3uspCa',
#  '5yY9lUy8nbvjM1Uyo1Uqoc',
#  '5SON8GFVi5chitOTgM8QIe',
#  '3tdjTdCCgKtwacsICCtPZZ',
#  '0OwX5aROoW1Iip8FV51Efg',
#  '4iiWcajF1fEUpwcUewc464',
#  '1dnsojUNfvhiztcITLzruj',
#  '7hav1MHURQf5SAoPk0egqh',
#  '6CUP2khYzdphXebxVTfPE3',
#  '5egD7A5x9AHdVO2fMo3Wbo',
#  '6YAxCn4juTWn5hWl2hzHGw',
#  '6vxU64pcIuQ38O015Zy4qj',
#  '1xcOYJxDa5pObgxY1r0I9c',
#  '4wBcaYqLPm7EtDVoJQORU4',
#  '7gHZGXSJzM29WA384suYY2',
#  '3kW4z2pIj5VY5fLjBrMRL5',
#  '5ngydCLbzCEdtu8SEOXhPU',
#  '2YaDRtIlQiZ5WDDB2YuEOC',
#  '70yhaHLp9STtzI2Kzba6Tr',
#  '6LQzYkmd8ADbKOOEVDnlG4',
#  '1po5LLTU8N62MCjysmaedr',
#  '74atKkOasLOVzvqB6mYgga',
#  '0crT33WQ4EUe65kMXBT6O6',
#  '1oGdVdYjeQvojGKDddxLQQ',
#  '2KvHC9z14GSl4YpkNMX384',
#  '7HcIAO5HqUlLcbOyJc2Y0K',
#  '56uXDJRCuoS7abX3SkzHKQ',
#  '68Dni7IE4VyPkTOH9mRWHr',
#  '2rTnVB1bvwxHtaIl4uVu7f',
#  '74fV8TuLZKVzSIOOGu8wwI',
#  '2QNndTbo9mvgOoOKJvpEl2',
#  '45jYIJVqddvpQzOE04GJ5D',
#  '57crda5Lx9OVaYCzb4Wrnd',
#  '5gNOINI5dXZVom2b36LMOd',
#  '16oi4OiKmkO51l60F5R9kR',
#  '6ChpgWt7s2ksM1Y3l0D9sk',
#  '5rFGVn8fCFjnRwCebW0XbS',
#  '5iUQMwxUPdJBFeGkePtM66',
#  '4cSSL3YafYjM3yjgFO1vJg',
#  '5TCBWmEBrin7etRa4Lswr1',
#  '5H4mXWKcicuLKDn4Jy0sK7',
#  '3KixNgUEaDtrKJVzdqjU5q',
#  '6fLVTVaHWaEfVKfEgbkf4D',
#  '05aZ9sAU1YXndHv0FMi9iW',
#  '4bl1HBZliBuYpFZjWgefE4',
#  '3yNVfRQlUPViUh8O2V9SQn',
#  '44IdNvMSJpOWWTqcExPXef',
#  '4zTPYAf5scZdp0LnwPPeWK',
#  '1Tfxi7N3DW4zvAuVjt9g8X',
#  '65FWIwYbpF4cSXLXykHUsV',
#  '2pmYug1wWd0WoK5tpbsbKL',
#  '0GaBIpyHvytM1UBYmqXu08',
#  '76PwajqH3ej4hnk9tgaJpp',
#  '6Q1NPLtp9IzcXmCutp3Qmo',
#  '01kOu8BA8yzAHx9LUidTi9',
#  '2UUnhLf51JSrji1FAbJ17G',
#  '3GOZyiebYv432EnVy9XwzE',
#  '3wFLWP0FcIqHK1wb1CPthQ',
#  '6PYnUsNEpYC7A4BS2sjw3L',
#  '6VS7wKwtvL2FvTupYSWZ9e',
#  '5nayhWICkQGMTkisxVMbRw',
#  '3V8UKqhEK5zBkBb6d6ub8i',
#  '29hrQIClzqNqMPO4bVWcjI',
#  '1eQBEelI2NCy7AUTerX0KS',
#  '0bjgQ24UZGwKikldIyEOgf',
#  '3eV2WT9YhfzkxbufnBF8wK',
#  '2FhEj9lvEIaJihjFprRrGt',
#  '71d7LaAgPcNcUopu3OzmP7',
#  '1JDhNQ0oOT7XpclZn3aQ8F',
#  '5rZlwNFl01HqLWBQGryKSm',
#  '1tkg4EHVoqnhR6iFEXb60y',
#  '2SxR5RitJdsG6wINvJLBSD',
#  '0H2s2OnUAcK3oHi1EbrXaw',
#  '2ppse4DOEFlzaW7Xu3U76r',
#  '6gxKUmycQX7uyMwJcweFjp',
#  '0fCwrjKfWxF3xQhZrYUw4T']

# %%
my_recommendation = random.choice(my_classification_id)
my_recommendation
# Out:
# '5SZzTVEEYwpLa9nlOV0P53'

# %%
def play_song(my_recommendation):
    return IFrame(src="https://open.spotify.com/embed/track/"+my_recommendation,
       width="320",
       height="80",
       frameborder="0",
       allowtransparency="true",
       allow="encrypted-media",
      )

# %%
play_song(my_recommendation)
# Out:
#         <iframe
#             width="320"
#             height="80"
#             src="https://open.spotify.com/embed/track/5SZzTVEEYwpLa9nlOV0P53?frameborder=0&allowtransparency=true&allow=encrypted-media"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# # Funcion Final

# %%
# Input user and check the top 100 list

user = input("select your song : ")

difflib.get_close_matches(user, df['song'])

if user in list(df['song']):
    computer = random.choice(df['song'])
    print('Recommendation:',computer)
elif difflib.get_close_matches(user, df['song']):
    computer = random.choice(df['song'])
    print('do you mean:',difflib.get_close_matches(user, df['song'])[0],'?')
    user2=input()
    
    if user2 == 'yes':
        print('Recommendation:',computer)
    elif user2 == 'no':
        print('Unfortunately, the song is not in the hot list!')
    else:
        print('please select yes or no:')
        user2=input()        
else: 
    print('Unfortunately, the song is not in the hot list!')
# Out:
# select your song : pollito pio
# Unfortunately, the song is not in the hot list!

# %%
#From the user's TRACK get the results

results = sp.search(q=user,limit=3,market="GB")


#GET THE TRACK_ID

track_id=track_id=results["tracks"]["items"][0]["id"]


#GET THE FEATURES OF THE USER'S TRACK AND CREATE A DF

users_track=sp.audio_features(results["tracks"]["items"][0]["id"] )

df_user=pd.DataFrame(users_track) 


#ADJUST THE COLUMNS OF USER'S TRACK

X = df_user[['danceability', 'energy', 'loudness', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo','duration_ms']].copy()

# SCALE THE DF (X)

X_scaled=my_scaler.transform(X)


#FINAL MODEL BASED ON X_SCALED

my_model_final=my_model.predict(X_scaled)



#SELECT THE GROUP OF SONGS FOR DOING THE RECOMENDATION

my_classification = df_final.loc[df_final['cluster']==my_model_final[0]]


#CREATE A LIST FOR THE RANDOM.CHOICE FUNCTION

my_classification_id = list(my_classification['id'])


#APPLY THE RANDOM FUNCTION AND GET THE TRACK RECOMMENDATION ID

my_recommendation = random.choice(my_classification_id)


#GET THE RECOMMENDATION
def play_song(my_recommendation):
    return IFrame(src="https://open.spotify.com/embed/track/"+my_recommendation,
       width="320",
       height="80",
       frameborder="0",
       allowtransparency="true",
       allow="encrypted-media",
      )

play_song(my_recommendation)
# Out:
# /Users/pabloherranzgonzalez/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but KMeans was fitted with feature names
#   warnings.warn(
#         <iframe
#             width="320"
#             height="80"
#             src="https://open.spotify.com/embed/track/0qxtQ8rf3W1nId3D2r0xH4?frameborder=0&allowtransparency=true&allow=encrypted-media"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
