# %%
import spotipy
import pandas as pd
import config
import spotipy
import json
from spotipy.oauth2 import SpotifyClientCredentials
import pprint

# %%
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id= config.client_id,
                                                           client_secret= config.client_secret))

# %%
df_prueba = pd.read_csv('df_final_spotify.csv')

# %%
df_prueba
# Out:
#       Unnamed: 0.1  Unnamed: 0  danceability  energy  loudness  speechiness  \
# 0                0           0         0.459   0.581    -6.575       0.0713
# 1                1           1         0.636   0.749    -4.197       0.0631
# 2                2           2         0.597   0.595    -7.328       0.2260
# 3                3           3         0.729   0.662    -4.851       0.0718
# 4                4           4         0.484   0.823    -9.324       0.1070
# ...            ...         ...           ...     ...       ...          ...
# 3551          3551        1994         0.868   0.550    -6.417       0.2260
# 3552          3552        1996         0.701   0.650    -6.313       0.1040
# 3553          3553        1997         0.630   0.446    -8.900       0.0351
# 3554          3554        1998         0.625   0.814    -5.181       0.0657
# 3555          3555        1999         0.288   0.638    -6.935       0.0779
#
# ...

# %%
df_prueba.id.nunique()
# Out:
# 3556

# %%
def drop_columns(df_final):
    df_final.drop(columns=["Unnamed: 0.1","Unnamed: 0"], inplace=True)
    return df_final

# %%
drop_columns(df_final)
# Out:
#       danceability  energy  loudness  speechiness  acousticness  \
# 0            0.459   0.581    -6.575       0.0713        0.3160
# 1            0.636   0.749    -4.197       0.0631        0.1950
# 2            0.597   0.595    -7.328       0.2260        0.5630
# 3            0.729   0.662    -4.851       0.0718        0.1260
# 4            0.484   0.823    -9.324       0.1070        0.0167
# ...            ...     ...       ...          ...           ...
# 3551         0.868   0.550    -6.417       0.2260        0.1830
# 3552         0.701   0.650    -6.313       0.1040        0.2910
# 3553         0.630   0.446    -8.900       0.0351        0.3370
# 3554         0.625   0.814    -5.181       0.0657        0.0172
# 3555         0.288   0.638    -6.935       0.0779        0.1330
#
#       instrumentalness  liveness  valence    tempo                      id  \
# 0             0.000000     0.124    0.490  176.195  4Agtk2MrapdZAVN7v6PuFO
# ...

# %%
df_final
# Out:
#       danceability  energy  loudness  speechiness  acousticness  \
# 0            0.459   0.581    -6.575       0.0713        0.3160
# 1            0.636   0.749    -4.197       0.0631        0.1950
# 2            0.597   0.595    -7.328       0.2260        0.5630
# 3            0.729   0.662    -4.851       0.0718        0.1260
# 4            0.484   0.823    -9.324       0.1070        0.0167
# ...            ...     ...       ...          ...           ...
# 3551         0.868   0.550    -6.417       0.2260        0.1830
# 3552         0.701   0.650    -6.313       0.1040        0.2910
# 3553         0.630   0.446    -8.900       0.0351        0.3370
# 3554         0.625   0.814    -5.181       0.0657        0.0172
# 3555         0.288   0.638    -6.935       0.0779        0.1330
#
#       instrumentalness  liveness  valence    tempo                      id  \
# 0             0.000000     0.124    0.490  176.195  4Agtk2MrapdZAVN7v6PuFO
# ...

# %%
playlist = sp.user_playlist_tracks("spotify", "5lSgExb6yTKfLusGag7bm7",market="GB")

# %%
def get_playlist_tracks(username, playlist_id):
    results = sp.user_playlist_tracks(username,playlist_id,market="GB")
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks

# %%
tracks=get_playlist_tracks("spotify", "5lSgExb6yTKfLusGag7bm7")

# %%
list_of_audio_features=[]
for item in range(0,1000):
    #print (tracks[item]["track"]["id"])
    list_of_audio_features.append(sp.audio_features(tracks[item]["track"]["id"])[0])

# %%
df=pd.DataFrame(list_of_audio_features)    
df=df[["danceability","energy","loudness","speechiness","acousticness",
    "instrumentalness","liveness","valence","tempo","id","duration_ms"]]

df
# Out:
#      danceability  energy  loudness  speechiness  acousticness  \
# 0           0.759   0.973    -6.278       0.0442      0.044300
# 1           0.555   0.826   -12.212       0.0316      0.000783
# 2           0.633   0.899    -3.798       0.0456      0.263000
# 3           0.683   0.906   -10.160       0.0710      0.013900
# 4           0.548   0.912    -5.686       0.0317      0.000129
# ..            ...     ...       ...          ...           ...
# 995         0.798   0.910    -9.256       0.0477      0.027200
# 996         0.468   0.875    -8.908       0.0363      0.001530
# 997         0.633   0.811    -5.600       0.0690      0.000642
# 998         0.496   0.957    -7.505       0.0497      0.015900
# 999         0.664   0.901    -7.493       0.0666      0.000187
#
#      instrumentalness  liveness  valence    tempo                      id  \
# 0              0.6900    0.1040   0.0955  123.995  44xPqYQFzpMVhpcDRzaBG5
# ...

# %%
df_final2=pd.concat([df, df_final])

# %%
df_final2
# Out:
#       danceability  energy  loudness  speechiness  acousticness  \
# 0            0.759   0.973    -6.278       0.0442      0.044300
# 1            0.555   0.826   -12.212       0.0316      0.000783
# 2            0.633   0.899    -3.798       0.0456      0.263000
# 3            0.683   0.906   -10.160       0.0710      0.013900
# 4            0.548   0.912    -5.686       0.0317      0.000129
# ...            ...     ...       ...          ...           ...
# 3551         0.868   0.550    -6.417       0.2260      0.183000
# 3552         0.701   0.650    -6.313       0.1040      0.291000
# 3553         0.630   0.446    -8.900       0.0351      0.337000
# 3554         0.625   0.814    -5.181       0.0657      0.017200
# 3555         0.288   0.638    -6.935       0.0779      0.133000
#
#       instrumentalness  liveness  valence    tempo                      id  \
# 0             0.690000    0.1040   0.0955  123.995  44xPqYQFzpMVhpcDRzaBG5
# ...

# %%
df_final2.to_csv("df_final2.csv")

# %%
df_final2
# Out:
#       danceability  energy  loudness  speechiness  acousticness  \
# 0            0.759   0.973    -6.278       0.0442      0.044300
# 1            0.555   0.826   -12.212       0.0316      0.000783
# 2            0.633   0.899    -3.798       0.0456      0.263000
# 3            0.683   0.906   -10.160       0.0710      0.013900
# 4            0.548   0.912    -5.686       0.0317      0.000129
# ...            ...     ...       ...          ...           ...
# 3551         0.868   0.550    -6.417       0.2260      0.183000
# 3552         0.701   0.650    -6.313       0.1040      0.291000
# 3553         0.630   0.446    -8.900       0.0351      0.337000
# 3554         0.625   0.814    -5.181       0.0657      0.017200
# 3555         0.288   0.638    -6.935       0.0779      0.133000
#
#       instrumentalness  liveness  valence    tempo                      id  \
# 0             0.690000    0.1040   0.0955  123.995  44xPqYQFzpMVhpcDRzaBG5
# ...

# %% [markdown]
# # Playlist 2

# %%
playlist = sp.user_playlist_tracks("spotify", "4D0h40lbOp3qwtQ0cHW7Wi",market="GB")

# %%
def get_playlist_tracks(username, playlist_id):
    results = sp.user_playlist_tracks(username,playlist_id,market="GB")
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks

# %%
tracks=get_playlist_tracks("spotify", "4D0h40lbOp3qwtQ0cHW7Wi")

# %%
list_of_audio_features2=[]
for item in range(0,234):
    #print (tracks[item]["track"]["id"])
    list_of_audio_features2.append(sp.audio_features(tracks[item]["track"]["id"])[0])

# %%
df2=pd.DataFrame(list_of_audio_features2)    
df2=df2[["danceability","energy","loudness","speechiness","acousticness",
    "instrumentalness","liveness","valence","tempo","id","duration_ms"]]

df2
# Out:
#      danceability  energy  loudness  speechiness  acousticness  \
# 0           0.644   0.703    -6.940       0.0349         0.553
# 1           0.639   0.729    -8.017       0.0378         0.471
# 2           0.718   0.704   -10.007       0.0544         0.455
# 3           0.503   0.655    -7.206       0.0334         0.174
# 4           0.718   0.737    -7.263       0.0372         0.632
# ..            ...     ...       ...          ...           ...
# 229         0.731   0.702    -8.326       0.0500         0.222
# 230         0.730   0.813    -3.898       0.1290         0.310
# 231         0.704   0.654   -11.656       0.0309         0.303
# 232         0.753   0.535   -10.073       0.0392         0.689
# 233         0.642   0.845    -4.830       0.1130         0.262
#
#      instrumentalness  liveness  valence    tempo                      id  \
# 0            0.001420    0.0909    0.533  174.824  7zridhiD9txjjYAcDoC0qY
# ...

# %%
df2.isna().any()
# Out:
# danceability        False
# energy              False
# loudness            False
# speechiness         False
# acousticness        False
# instrumentalness    False
# liveness            False
# valence             False
# tempo               False
# id                  False
# duration_ms         False
# dtype: bool

# %% [markdown]
# # Playlist 3

# %%
playlist = sp.user_playlist_tracks("spotify", "6UyPQhXg9bK5Ahg4mmH6sh",market="GB")

# %%
def get_playlist_tracks(username, playlist_id):
    results = sp.user_playlist_tracks(username,playlist_id,market="GB")
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks

# %%
tracks3=get_playlist_tracks("spotify", "4D0h40lbOp3qwtQ0cHW7Wi")

# %%
list_of_audio_features3=[]
for item in range(0,234):
    #print (tracks[item]["track"]["id"])
    list_of_audio_features3.append(sp.audio_features(tracks3[item]["track"]["id"])[0])

# %%
df3=pd.DataFrame(list_of_audio_features3)    
df3=df3[["danceability","energy","loudness","speechiness","acousticness",
    "instrumentalness","liveness","valence","tempo","id","duration_ms"]]

df3
# Out:
#      danceability  energy  loudness  speechiness  acousticness  \
# 0           0.644   0.703    -6.940       0.0349         0.553
# 1           0.639   0.729    -8.017       0.0378         0.471
# 2           0.718   0.704   -10.007       0.0544         0.455
# 3           0.503   0.655    -7.206       0.0334         0.174
# 4           0.718   0.737    -7.263       0.0372         0.632
# ..            ...     ...       ...          ...           ...
# 229         0.731   0.702    -8.326       0.0500         0.222
# 230         0.730   0.813    -3.898       0.1290         0.310
# 231         0.704   0.654   -11.656       0.0309         0.303
# 232         0.753   0.535   -10.073       0.0392         0.689
# 233         0.642   0.845    -4.830       0.1130         0.262
#
#      instrumentalness  liveness  valence    tempo                      id  \
# 0            0.001420    0.0909    0.533  174.824  7zridhiD9txjjYAcDoC0qY
# ...

# %% [markdown]
# # Playlist 4

# %%
playlist = sp.user_playlist_tracks("spotify", "1tb1Jk1T8GQrsEXqS2HoKu",market="GB")

# %%
def get_playlist_tracks(username, playlist_id):
    results = sp.user_playlist_tracks(username,playlist_id,market="GB")
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks

# %%
tracks=get_playlist_tracks("spotify", "1tb1Jk1T8GQrsEXqS2HoKu")

# %%
list_of_audio_features=[]
for item in range(0,500):
    #print (tracks[item]["track"]["id"])
    list_of_audio_features.append(sp.audio_features(tracks[item]["track"]["id"])[0])

# %%
df4=pd.DataFrame(list_of_audio_features)    
df4=df4[["danceability","energy","loudness","speechiness","acousticness",
    "instrumentalness","liveness","valence","tempo","id","duration_ms"]]

df4
# Out:
#      danceability  energy  loudness  speechiness  acousticness  \
# 0           0.298   0.581    -8.133       0.0289      0.381000
# 1           0.522   0.853    -5.861       0.0383      0.000074
# 2           0.374   0.995    -7.644       0.0889      0.107000
# 3           0.382   0.996    -4.119       0.1040      0.002080
# 4           0.595   0.788    -7.167       0.0601      0.020800
# ..            ...     ...       ...          ...           ...
# 495         0.326   0.995    -4.380       0.1470      0.000094
# 496         0.454   0.913    -4.008       0.1070      0.408000
# 497         0.342   0.910    -7.748       0.0758      0.000040
# 498         0.543   0.836    -9.110       0.0353      0.000647
# 499         0.429   0.631   -11.514       0.0769      0.000078
#
#      instrumentalness  liveness  valence    tempo                      id  \
# 0            0.022400    0.1720    0.260   89.285  2g02rt0UFudctbAnmJsm22
# ...

# %% [markdown]
# # Playlist 5

# %%
playlist = sp.user_playlist_tracks("spotify", "0XOIK4m26aeYSD61E5nSVW",market="GB")

# %%
def get_playlist_tracks(username, playlist_id):
    results = sp.user_playlist_tracks(username,playlist_id,market="GB")
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks

# %%
tracks=get_playlist_tracks("spotify", "0XOIK4m26aeYSD61E5nSVW")

# %%
try:
    list_of_audio_features5=[]
    for item in range(0,1500):
    #print (tracks[item]["track"]["id"])
        list_of_audio_features5.append(sp.audio_features(tracks[item]["track"]["id"])[0])
        
except:
    pass

# %%
df5=pd.DataFrame(list_of_audio_features)    
df5=df5[["danceability","energy","loudness","speechiness","acousticness",
    "instrumentalness","liveness","valence","tempo","id","duration_ms"]]

df5
# Out:
#      danceability  energy  loudness  speechiness  acousticness  \
# 0           0.620   0.573   -11.893       0.0423        0.2710
# 1           0.698   0.912    -8.993       0.0675        0.0145
# 2           0.408   0.480   -11.017       0.0266        0.1550
# 3           0.612   0.600   -10.945       0.0327        0.1500
# 4           0.636   0.264   -14.567       0.0263        0.5930
# ..            ...     ...       ...          ...           ...
# 419         0.555   0.440   -11.737       0.0274        0.5110
# 420         0.561   0.945    -6.086       0.0444        0.0869
# 421         0.468   0.571   -14.099       0.0590        0.2490
# 422         0.475   0.583   -12.456       0.0407        0.0720
# 423         0.794   0.730    -6.067       0.0332        0.0538
#
#      instrumentalness  liveness  valence    tempo                      id  \
# 0            0.000000    0.0607    0.897   81.548  0ikz6tENMONtK6qGkOrU3c
# ...

# %% [markdown]
# # Playlist 6

# %%
playlist = sp.user_playlist_tracks("spotify", "6EBJshQEFG3GJvh5Of79GU",market="GB")

# %%
def get_playlist_tracks(username, playlist_id):
    results = sp.user_playlist_tracks(username,playlist_id,market="GB")
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks

# %%
tracks=get_playlist_tracks("spotify", "6EBJshQEFG3GJvh5Of79GU")

# %%
list_of_audio_features6=[]
for item in range(0,1000):
    #print (tracks[item]["track"]["id"])
    list_of_audio_features6.append(sp.audio_features(tracks[item]["track"]["id"])[0])

# %%
df6=pd.DataFrame(list_of_audio_features6)    
df6=df6[["danceability","energy","loudness","speechiness","acousticness",
    "instrumentalness","liveness","valence","tempo","id","duration_ms"]]

df6
# Out:
#      danceability  energy  loudness  speechiness  acousticness  \
# 0           0.673   0.712    -5.966        0.365       0.09200
# 1           0.801   0.663    -7.118        0.243       0.00168
# 2           0.600   0.779   -10.369        0.408       0.27400
# 3           0.656   0.491   -11.671        0.431       0.03990
# 4           0.745   0.858    -2.221        0.237       0.28000
# ..            ...     ...       ...          ...           ...
# 995         0.651   0.579    -5.494        0.311       0.46300
# 996         0.795   0.793    -5.319        0.231       0.13100
# 997         0.794   0.628    -6.877        0.130       0.10600
# 998         0.700   0.935    -1.449        0.385       0.18600
# 999         0.771   0.527    -6.797        0.230       0.20500
#
#      instrumentalness  liveness  valence    tempo                      id  \
# 0            0.000000    0.4320    0.540   91.802  2uyfLA0lkVWWljrkDkUT0q
# ...

# %% [markdown]
# # Playlist 7

# %%
playlist = sp.user_playlist_tracks("spotify", "37i9dQZF1DXdD040nrEzxm",market="GB")

# %%
def get_playlist_tracks(username, playlist_id):
    results = sp.user_playlist_tracks(username,playlist_id,market="GB")
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks

# %%
tracks=get_playlist_tracks("spotify", "37i9dQZF1DXdD040nrEzxm")

# %%
list_of_audio_features7=[]
for item in range(0,100):
    #print (tracks[item]["track"]["id"])
    list_of_audio_features7.append(sp.audio_features(tracks[item]["track"]["id"])[0])

# %%
df7=pd.DataFrame(list_of_audio_features7)    
df7=df7[["danceability","energy","loudness","speechiness","acousticness",
    "instrumentalness","liveness","valence","tempo","id","duration_ms"]]

df7
# Out:
#     danceability  energy  loudness  speechiness  acousticness  \
# 0          0.615   0.575    -6.515       0.4000        0.2600
# 1          0.697   0.653    -7.284       0.1020        0.1660
# 2          0.805   0.525    -7.376       0.0638        0.1190
# 3          0.852   0.666    -6.065       0.1070        0.0158
# 4          0.891   0.614    -7.749       0.0745        0.0431
# ..           ...     ...       ...          ...           ...
# 95         0.850   0.799    -6.875       0.0507        0.0937
# 96         0.781   0.612    -5.531       0.0778        0.4340
# 97         0.767   0.706    -7.437       0.2620        0.1930
# 98         0.506   0.682    -5.589       0.1460        0.1870
# 99         0.784   0.771    -3.897       0.0678        0.2050
#
#     instrumentalness  liveness  valence    tempo                      id  \
# 0           0.000004    0.3240    0.552  134.791  29e2gdZN35wxeGgDtkXjIa
# ...

# %% [markdown]
# # Playlist 8

# %%
playlist = sp.user_playlist_tracks("spotify", "6yPiKpy7evrwvZodByKvM9",market="GB")

# %%
def get_playlist_tracks(username, playlist_id):
    results = sp.user_playlist_tracks(username,playlist_id,market="GB")
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks

# %%
tracks=get_playlist_tracks("spotify", "6yPiKpy7evrwvZodByKvM9")

# %%
try:

    list_of_audio_features8=[]
    for item in range(0,1000):
    #print (tracks[item]["track"]["id"])
        list_of_audio_features8.append(sp.audio_features(tracks[item]["track"]["id"])[0])
        
except:
    pass

# %%
df8=pd.DataFrame(list_of_audio_features8)    
df8=df8[["danceability","energy","loudness","speechiness","acousticness",
    "instrumentalness","liveness","valence","tempo","id","duration_ms"]]

df8
# Out:
#     danceability  energy  loudness  speechiness  acousticness  \
# 0          0.406  0.4450   -13.355       0.0745      0.093000
# 1          0.419  0.5650   -11.565       0.0347      0.137000
# 2          0.532  0.3030   -13.076       0.0311      0.587000
# 3          0.717  0.8000    -5.794       0.0497      0.371000
# 4          0.571  0.7240    -5.967       0.0260      0.023100
# 5          0.579  0.7770    -7.505       0.0304      0.017700
# 6          0.606  0.6380    -6.994       0.0339      0.043400
# 7          0.573  0.9320    -2.862       0.0488      0.001520
# 8          0.451  0.8890    -3.838       0.0379      0.312000
# 9          0.451  0.8890    -3.838       0.0379      0.312000
# 10         0.600  0.5350    -8.178       0.0298      0.001540
# 11         0.341  0.8810    -3.558       0.0411      0.003850
# 12         0.598  0.8540    -7.584       0.0422      0.047700
# 13         0.393  0.1480   -16.119       0.0303      0.928000
# ...

# %%
df_final=pd.concat([df2, df3, df4, df5, df6, df7,df8, df_prueba])

# %%
df_final
# Out:
#       danceability  energy  loudness  speechiness  acousticness  \
# 0            0.644   0.703    -6.940       0.0349        0.5530
# 1            0.639   0.729    -8.017       0.0378        0.4710
# 2            0.718   0.704   -10.007       0.0544        0.4550
# 3            0.503   0.655    -7.206       0.0334        0.1740
# 4            0.718   0.737    -7.263       0.0372        0.6320
# ...            ...     ...       ...          ...           ...
# 3551         0.868   0.550    -6.417       0.2260        0.1830
# 3552         0.701   0.650    -6.313       0.1040        0.2910
# 3553         0.630   0.446    -8.900       0.0351        0.3370
# 3554         0.625   0.814    -5.181       0.0657        0.0172
# 3555         0.288   0.638    -6.935       0.0779        0.1330
#
#       instrumentalness  liveness  valence    tempo                      id  \
# 0             0.001420    0.0909    0.533  174.824  7zridhiD9txjjYAcDoC0qY
# ...

# %%
df_final.id.nunique()
# Out:
# 5734

# %%
df_final['id'].duplicated().any()
# Out:
# True

# %%
df_final.id.nunique()
# Out:
# 5734

# %%
df_final.id.duplicated().sum()
# Out:
# 336

# %%
df_final
# Out:
#       danceability  energy  loudness  speechiness  acousticness  \
# 0            0.644   0.703    -6.940       0.0349        0.5530
# 1            0.639   0.729    -8.017       0.0378        0.4710
# 2            0.718   0.704   -10.007       0.0544        0.4550
# 3            0.503   0.655    -7.206       0.0334        0.1740
# 4            0.718   0.737    -7.263       0.0372        0.6320
# ...            ...     ...       ...          ...           ...
# 3551         0.868   0.550    -6.417       0.2260        0.1830
# 3552         0.701   0.650    -6.313       0.1040        0.2910
# 3553         0.630   0.446    -8.900       0.0351        0.3370
# 3554         0.625   0.814    -5.181       0.0657        0.0172
# 3555         0.288   0.638    -6.935       0.0779        0.1330
#
#       instrumentalness  liveness  valence    tempo                      id  \
# 0             0.001420    0.0909    0.533  174.824  7zridhiD9txjjYAcDoC0qY
# ...

# %%
df_definitivo = df_final.drop_duplicates(subset = "id")

# %%
df_definitivo
# Out:
#       danceability  energy  loudness  speechiness  acousticness  \
# 0            0.644   0.703    -6.940       0.0349        0.5530
# 1            0.639   0.729    -8.017       0.0378        0.4710
# 2            0.718   0.704   -10.007       0.0544        0.4550
# 3            0.503   0.655    -7.206       0.0334        0.1740
# 4            0.718   0.737    -7.263       0.0372        0.6320
# ...            ...     ...       ...          ...           ...
# 3551         0.868   0.550    -6.417       0.2260        0.1830
# 3552         0.701   0.650    -6.313       0.1040        0.2910
# 3553         0.630   0.446    -8.900       0.0351        0.3370
# 3554         0.625   0.814    -5.181       0.0657        0.0172
# 3555         0.288   0.638    -6.935       0.0779        0.1330
#
#       instrumentalness  liveness  valence    tempo                      id  \
# 0             0.001420    0.0909    0.533  174.824  7zridhiD9txjjYAcDoC0qY
# ...

# %%
df_definitivo.to_csv("df_final_spotify.csv", index=False)

# %%
df_prueba = pd.read_csv('df_final_spotify.csv')
df_prueba
# Out:
#       danceability  energy  loudness  speechiness  acousticness  \
# 0            0.644   0.703    -6.940       0.0349        0.5530
# 1            0.639   0.729    -8.017       0.0378        0.4710
# 2            0.718   0.704   -10.007       0.0544        0.4550
# 3            0.503   0.655    -7.206       0.0334        0.1740
# 4            0.718   0.737    -7.263       0.0372        0.6320
# ...            ...     ...       ...          ...           ...
# 5729         0.868   0.550    -6.417       0.2260        0.1830
# 5730         0.701   0.650    -6.313       0.1040        0.2910
# 5731         0.630   0.446    -8.900       0.0351        0.3370
# 5732         0.625   0.814    -5.181       0.0657        0.0172
# 5733         0.288   0.638    -6.935       0.0779        0.1330
#
#       instrumentalness  liveness  valence    tempo                      id  \
# 0             0.001420    0.0909    0.533  174.824  7zridhiD9txjjYAcDoC0qY
# ...

# %%
df_prueba.id.nunique()
# Out:
# 5734

# %% [markdown]
# # Playlist 9

# %%
playlist = sp.user_playlist_tracks("spotify", "0cnvvolxcVbBrSDmpudjTt",market="GB")

# %%
def get_playlist_tracks(username, playlist_id):
    results = sp.user_playlist_tracks(username,playlist_id,market="GB")
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks

# %%
tracks=get_playlist_tracks("spotify", "0cnvvolxcVbBrSDmpudjTt")

# %%
list_of_audio_features9=[]
for item in range(0,450):
    #print (tracks[item]["track"]["id"])
    list_of_audio_features9.append(sp.audio_features(tracks[item]["track"]["id"])[0])

# %%
df9=pd.DataFrame(list_of_audio_features9)    
df9=df9[["danceability","energy","loudness","speechiness","acousticness",
    "instrumentalness","liveness","valence","tempo","id","duration_ms"]]

df9
# Out:
#      danceability  energy  loudness  speechiness  acousticness  \
# 0           0.449   0.576   -10.640       0.0329       0.71200
# 1           0.404   0.902    -3.880       0.0665       0.57700
# 2           0.402   0.552   -10.158       0.0258       0.02800
# 3           0.338   0.340   -12.049       0.0339       0.58000
# 4           0.490   0.724    -9.581       0.0366       0.00976
# ..            ...     ...       ...          ...           ...
# 445         0.285   0.322   -16.580       0.0445       0.36700
# 446         0.272   0.684    -9.728       0.0505       0.09980
# 447         0.550   0.490   -10.732       0.0572       0.36800
# 448         0.581   0.806    -8.158       0.0335       0.15600
# 449         0.349   0.941    -6.066       0.0712       0.09820
#
#      instrumentalness  liveness  valence    tempo                      id  \
# 0            0.000000    0.1650    0.599   95.653  0Muez8ucUqZMXIaYONOgF2
# ...

# %% [markdown]
# # Playlist 10

# %%
playlist = sp.user_playlist_tracks("spotify", "4fA7cKqmVwGp0puGSFRFZl",market="GB")

# %%
def get_playlist_tracks(username, playlist_id):
    results = sp.user_playlist_tracks(username,playlist_id,market="GB")
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks

# %%
tracks=get_playlist_tracks("spotify", "4fA7cKqmVwGp0puGSFRFZl")

# %%
list_of_audio_features10=[]
for item in range(0,1400):
    #print (tracks[item]["track"]["id"])
    list_of_audio_features10.append(sp.audio_features(tracks[item]["track"]["id"])[0])

# %%
df10=pd.DataFrame(list_of_audio_features9)    
df10=df10[["danceability","energy","loudness","speechiness","acousticness",
    "instrumentalness","liveness","valence","tempo","id","duration_ms"]]

df10
# Out:
#      danceability  energy  loudness  speechiness  acousticness  \
# 0           0.449   0.576   -10.640       0.0329       0.71200
# 1           0.404   0.902    -3.880       0.0665       0.57700
# 2           0.402   0.552   -10.158       0.0258       0.02800
# 3           0.338   0.340   -12.049       0.0339       0.58000
# 4           0.490   0.724    -9.581       0.0366       0.00976
# ..            ...     ...       ...          ...           ...
# 445         0.285   0.322   -16.580       0.0445       0.36700
# 446         0.272   0.684    -9.728       0.0505       0.09980
# 447         0.550   0.490   -10.732       0.0572       0.36800
# 448         0.581   0.806    -8.158       0.0335       0.15600
# 449         0.349   0.941    -6.066       0.0712       0.09820
#
#      instrumentalness  liveness  valence    tempo                      id  \
# 0            0.000000    0.1650    0.599   95.653  0Muez8ucUqZMXIaYONOgF2
# ...

# %%
df_prueba
# Out:
#       danceability  energy  loudness  speechiness  acousticness  \
# 0            0.644   0.703    -6.940       0.0349        0.5530
# 1            0.639   0.729    -8.017       0.0378        0.4710
# 2            0.718   0.704   -10.007       0.0544        0.4550
# 3            0.503   0.655    -7.206       0.0334        0.1740
# 4            0.718   0.737    -7.263       0.0372        0.6320
# ...            ...     ...       ...          ...           ...
# 5729         0.868   0.550    -6.417       0.2260        0.1830
# 5730         0.701   0.650    -6.313       0.1040        0.2910
# 5731         0.630   0.446    -8.900       0.0351        0.3370
# 5732         0.625   0.814    -5.181       0.0657        0.0172
# 5733         0.288   0.638    -6.935       0.0779        0.1330
#
#       instrumentalness  liveness  valence    tempo                      id  \
# 0             0.001420    0.0909    0.533  174.824  7zridhiD9txjjYAcDoC0qY
# ...

# %%
df_final3=pd.concat([df9, df10, df_prueba])
df_final3
# Out:
#       danceability  energy  loudness  speechiness  acousticness  \
# 0            0.449   0.576   -10.640       0.0329       0.71200
# 1            0.404   0.902    -3.880       0.0665       0.57700
# 2            0.402   0.552   -10.158       0.0258       0.02800
# 3            0.338   0.340   -12.049       0.0339       0.58000
# 4            0.490   0.724    -9.581       0.0366       0.00976
# ...            ...     ...       ...          ...           ...
# 5729         0.868   0.550    -6.417       0.2260       0.18300
# 5730         0.701   0.650    -6.313       0.1040       0.29100
# 5731         0.630   0.446    -8.900       0.0351       0.33700
# 5732         0.625   0.814    -5.181       0.0657       0.01720
# 5733         0.288   0.638    -6.935       0.0779       0.13300
#
#       instrumentalness  liveness  valence    tempo                      id  \
# 0             0.000000    0.1650    0.599   95.653  0Muez8ucUqZMXIaYONOgF2
# ...

# %%
df_final3.id.nunique()
# Out:
# 6133

# %%
df_final3 = df_final3.drop_duplicates(subset = "id")
df_final3
# Out:
#       danceability  energy  loudness  speechiness  acousticness  \
# 0            0.449   0.576   -10.640       0.0329       0.71200
# 1            0.404   0.902    -3.880       0.0665       0.57700
# 2            0.402   0.552   -10.158       0.0258       0.02800
# 3            0.338   0.340   -12.049       0.0339       0.58000
# 4            0.490   0.724    -9.581       0.0366       0.00976
# ...            ...     ...       ...          ...           ...
# 5729         0.868   0.550    -6.417       0.2260       0.18300
# 5730         0.701   0.650    -6.313       0.1040       0.29100
# 5731         0.630   0.446    -8.900       0.0351       0.33700
# 5732         0.625   0.814    -5.181       0.0657       0.01720
# 5733         0.288   0.638    -6.935       0.0779       0.13300
#
#       instrumentalness  liveness  valence    tempo                      id  \
# 0             0.000000    0.1650    0.599   95.653  0Muez8ucUqZMXIaYONOgF2
# ...

# %%
df_final3.to_csv("df_final_spotify.csv", index=False)

# %%
df=pd.read_csv('df_final_spotify.csv')
df
# Out:
#       danceability  energy  loudness  speechiness  acousticness  \
# 0            0.449   0.576   -10.640       0.0329       0.71200
# 1            0.404   0.902    -3.880       0.0665       0.57700
# 2            0.402   0.552   -10.158       0.0258       0.02800
# 3            0.338   0.340   -12.049       0.0339       0.58000
# 4            0.490   0.724    -9.581       0.0366       0.00976
# ...            ...     ...       ...          ...           ...
# 6128         0.868   0.550    -6.417       0.2260       0.18300
# 6129         0.701   0.650    -6.313       0.1040       0.29100
# 6130         0.630   0.446    -8.900       0.0351       0.33700
# 6131         0.625   0.814    -5.181       0.0657       0.01720
# 6132         0.288   0.638    -6.935       0.0779       0.13300
#
#       instrumentalness  liveness  valence    tempo                      id  \
# 0             0.000000    0.1650    0.599   95.653  0Muez8ucUqZMXIaYONOgF2
# ...
